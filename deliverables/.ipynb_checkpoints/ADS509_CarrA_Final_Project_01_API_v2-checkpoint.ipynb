# %% [markdown]
# # 509 Final Project

# %% [markdown]
# ## Rsolve dependencies

# %%
! pip install newsapi-python
# Out:
# Requirement already satisfied: newsapi-python in /Users/davidfriesen/opt/anaconda3/lib/python3.9/site-packages (0.2.7)
# Requirement already satisfied: requests<3.0.0 in /Users/davidfriesen/opt/anaconda3/lib/python3.9/site-packages (from newsapi-python) (2.26.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/davidfriesen/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0->newsapi-python) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/davidfriesen/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0->newsapi-python) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/davidfriesen/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0->newsapi-python) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/davidfriesen/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0->newsapi-python) (1.26.7)

# %% [markdown]
# ## Globally import libraries

# %%
import numpy as np
import pandas as pd
import pymysql as mysql
import matplotlib.pyplot as plt
import os
import shutil
import re
import logging
import time
import zipfile
import requests
from bs4 import BeautifulSoup
import datetime
import re
import regex as rex
from collections import defaultdict, Counter
import random
#import mysql.connector

# Set pandas global options
pd.options.display.max_rows = 17

# %%
today = datetime.date.today()
print(today)
print(type(today))
# Out:
# 2023-06-03
# <class 'datetime.date'>

# %% [markdown]
# ## Connect to NewsAPI client

# %%
from newsapi import NewsApiClient

api_key = os.environ['NewsAPIKey']

# Init
newsapi = NewsApiClient(api_key=api_key)

# %% [markdown]
# ## Pull article info from API

# %% [markdown]
# # /v2/top-headlines/sources
# sources = newsapi.get_sources()
# print(sources)

# %%
def news_api_urls(q=None,
                  s=None,
                  d_from='2023-05-01',
                  d_to='2023-05-31',
                  api_lst=[]):
    all_articles = newsapi.get_everything(q=q,
                                          sources=s,
                                          from_param=d_from,
                                          to=d_to,
                                          language='en',
                                          sort_by='relevancy',
                                          page=1)

    print(type(all_articles))
    print(all_articles)
    #print('Article list: ', all_articles['articles'])
    for article in all_articles['articles']:
        print('Source ID:', article['source']['id'])
        print('Source name:', article['source']['name'])
        print('Author:', article['author'])
        print('Title:', article['title'])
        print('URL:', article['url'])
        print('Publish date:', article['publishedAt'])
        print('Article text:', article['content'], '\n')

    # Create a list of tuples from the dictionary data
    source_data01 = [(a['source']['name'],
                      a['author'],
                      a['title'],
                      a['url'],
                      a['publishedAt'],
                      a['content'])
                     for a in all_articles['articles']]

    api_lst.extend(source_data01)
    #print(api_lst)
    print(len(api_lst))

# %% [markdown]
# ## Connect to API to access URLs

# %% [markdown]
# ### Set API filter parameters

# %%
# Citation comes from Allsides Media Bias Chart
#source_lst = ['cnn', 'reuters', 'fox-news']
#source_lst = ['cnn', 'newsweek', 'fox-news']
#source_lst = ['newsweek']

#date_lst = ['2023-06-01', '2023-05-31']
#date_lst = ['2023-05-30', '2023-05-29']
date_lst = ['2023-05-30']

# Comes from academci text (fill in citation from DF)
q_word_lst = ['gender OR male OR female OR transgender', 'security AND (social OR national)',
              'justice OR surveillance', 'healthcare OR "health care"',
              '(political AND (bias OR party)) OR republican OR democrat OR election', '(policy AND (drug OR "affirmative action")) OR regulate OR regulation']

# %% [markdown]
# ### Access API

# %%
api_record_lst01 = []
for s in source_lst:
    print(f'Source: {s}')
    for d in date_lst:
        print(f'Date: {d}')
        for q in q_word_lst:
            print(f'Query word: {q}')
            time.sleep(5 + 11 * random.random())
            news_api_urls(q=q,
                          s=s,
                          d_from=d,
                          d_to=d,
                          api_lst=api_record_lst01)
            print(s, d, q)
    time.sleep(10 + 13 * random.random())

print(api_record_lst01)
print(len(api_record_lst01))
# Out:
# Source: bbc-news
# Date: 2023-05-30
# Query word: gender OR male OR female OR transgender
# <class 'dict'>
# {'status': 'ok', 'totalResults': 10, 'articles': [{'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'https://www.facebook.com/bbcnews', 'title':
# Source ID: bbc-news
# Source name: BBC News
# Author: https://www.facebook.com/bbcnews
# Title: AI 'godfather' Yoshua Bengio feels 'lost' over life's work
# URL: https://www.bbc.co.uk/news/technology-65760449
# Publish date: 2023-05-30T23:05:26Z
# Article text: One of the so-called "godfathers" of Artificial Intelligence (AI) has said he would have prioritised safety over usefulness had he realised the pace at which it would evolve.
# Prof Yoshua Bengio told… [+3465 chars]
#
# Source ID: bbc-news
# Source name: BBC News
# Author: https://www.facebook.com/bbcnews
# Title: Zones planned to protect wild salmon from sea lice
# URL: https://www.bbc.co.uk/news/uk-scotland-65754221
# Publish date: 2023-05-30T21:42:40Z
# Article text: An extensive network of wild salmon protection zones is being proposed along Scotland's west coast.
# Industry regulator Sepa wants to halt the long-term decline of the Atlantic wild salmon population… [+5116 chars]
#
# Source ID: bbc-news
# Source name: BBC News
# Author: https://www.facebook.com/bbcnews
# Title: Vaping: Government plans underage crackdown
# URL: https://www.bbc.co.uk/news/uk-65749389
# Publish date: 2023-05-30T00:02:53Z
# Article text: A loophole allowing retailers to give free vape samples to children is set to be closed under government plans to curb their use among young people.
# A new crackdown on vape marketing would prevent … [+6746 chars]
#
# 32
# bbc-news 2023-05-30 (policy AND (drug OR "affirmative action")) OR regulate OR regulation
# Source: associated-press
# Date: 2023-05-30
# Query word: gender OR male OR female OR transgender
# <class 'dict'>
# {'status': 'ok', 'totalResults': 2, 'articles': [{'source': {'id': 'associated-press', 'name': 'Associated Press'}, 'author': 'ap news', 'title': 'LGBTQ+ activists call for new strategies to promote equality after TARGET backlash...', 'description': 'RICHMOND, Va. (AP) — Following Target’s announcement last week  that it removed products and relocated Pride displays to the back of certain stores in the South, activists in the LGBTQ+ community are calling for new campaigns to convince corporate leaders not…', 'url': 'https://apnews.com/article/lgbtq-target-pride-month-gay-transgender-a6872f755096647b0732cd5313b1b4b7', 'urlToImage': 'https://storage.googleapis.com/afs-prod/media/d7361d4031324490aad2cc2414d1de3a/3000.webp', 'publishedAt': '2023-05-30T11:00:04Z', 'content': 'LGBTQ+ activists call for new strategies to promote equality after Target backlashRICHMOND, Va. (AP) — Following Target’s announcement last week that it removed products and relocated Pride displays … [+6038 chars]'}, {'source': {'id': 'associated-press', 'name': 'Associated Press'}, 'author': 'By COLLIN BINKLEY and EMILY SWANSON - Associated Press', 'title': "Most in US say don't ban race in college admissions but its role should be small: AP-NORC poll", 'description': 'As the Supreme Court decides the fate of affirmative action, most people in the U.S. say the court should allow consideration of race as part of the admissions process. Yet few believe students’ race should play a significant role in…', 'url': 'https://apnews.com/article/affirmative-action-race-college-admissions-supreme-court-1b587cb63edc2fa192ad9ec5f27979e5', 'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/assets/v3/editorial/1/4a/14a9cbd2-ab48-5d58-8b80-d4e181168f82/6475d26157741.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize', 'publishedAt': '2023-05-30T09:29:00Z', 'content': 'Gift this article\r\nBy COLLIN BINKLEY and EMILY SWANSON - Associated Press\r\nWASHINGTON (AP) As the Supreme Court decides the fate of affirmative action, most U.S. adults say the court should allow col… [+7190 chars]'}]}
# Source ID: associated-press
# Source name: Associated Press
# Author: ap news
# Title: LGBTQ+ activists call for new strategies to promote equality after TARGET backlash...
# URL: https://apnews.com/article/lgbtq-target-pride-month-gay-transgender-a6872f755096647b0732cd5313b1b4b7
# Publish date: 2023-05-30T11:00:04Z
# Article text: LGBTQ+ activists call for new strategies to promote equality after Target backlashRICHMOND, Va. (AP) — Following Target’s announcement last week that it removed products and relocated Pride displays … [+6038 chars]
#
# Source ID: associated-press
# Source name: Associated Press
# Author: By COLLIN BINKLEY and EMILY SWANSON - Associated Press
# Title: Most in US say don't ban race in college admissions but its role should be small: AP-NORC poll
# URL: https://apnews.com/article/affirmative-action-race-college-admissions-supreme-court-1b587cb63edc2fa192ad9ec5f27979e5
# Publish date: 2023-05-30T09:29:00Z
# Article text: Gift this article
# By COLLIN BINKLEY and EMILY SWANSON - Associated Press
# WASHINGTON (AP) As the Supreme Court decides the fate of affirmative action, most U.S. adults say the court should allow col… [+7190 chars]
#
# 34
# associated-press 2023-05-30 gender OR male OR female OR transgender
# Query word: security AND (social OR national)
# <class 'dict'>
# {'status': 'ok', 'totalResults': 0, 'articles': []}
# 34
# associated-press 2023-05-30 security AND (social OR national)
# Query word: justice OR surveillance
# <class 'dict'>
# {'status': 'ok', 'totalResults': 1, 'articles': [{'source': {'id': 'associated-press', 'name': 'Associated Press'}, 'author': 'By MICHAEL LIEDTKE - AP Technology Writer', 'title': 'The day has arrived for Elizabeth Holmes to report to a Texas prison', 'description': 'Disgraced Theranos CEO Elizabeth Holmes on Tuesday will be moving to her new home —-a federal prison where she has been sentenced to spend the next 11 years for overseeing a blood-testing hoax that became a parable about greed and…', 'url': 'https://apnews.com/article/elizabeth-holmes-theranos-prison-fraud-texas-71bcdf58a0db73252cc2697fb9f73c8a', 'urlToImage': 'https://bloximages.chicago2.vip.townnews.com/billingsgazette.com/content/tncms/assets/v3/editorial/8/25/8251c73b-ced3-50a6-9f15-aacc6fbf98f3/6475e093cb27c.image.jpg?crop=1773%2C931%2C0%2C118&resize=1200%2C630&order=crop%2Cresize', 'publishedAt': '2023-05-30T12:26:50Z', 'content': 'Gift this article\r\nBy MICHAEL LIEDTKE - AP Technology Writer\r\nDisgraced Theranos CEO Elizabeth Holmes is scheduled to move to her new home -a federal prison where she has been sentenced to spend the … [+5009 chars]'}]}
# Source ID: associated-press
# Source name: Associated Press
# Author: By MICHAEL LIEDTKE - AP Technology Writer
# Title: The day has arrived for Elizabeth Holmes to report to a Texas prison
# URL: https://apnews.com/article/elizabeth-holmes-theranos-prison-fraud-texas-71bcdf58a0db73252cc2697fb9f73c8a
# Publish date: 2023-05-30T12:26:50Z
# Article text: Gift this article
# By MICHAEL LIEDTKE - AP Technology Writer
# Disgraced Theranos CEO Elizabeth Holmes is scheduled to move to her new home -a federal prison where she has been sentenced to spend the … [+5009 chars]
#
# 35
# associated-press 2023-05-30 justice OR surveillance
# Query word: healthcare OR "health care"
# <class 'dict'>
# {'status': 'ok', 'totalResults': 3, 'articles': [{'source': {'id': 'associated-press', 'name': 'Associated Press'}, 'author': 'ap news', 'title': '9 shot, including minors, as gunfire erupts in Hollywood, Florida...', 'description': 'HOLLYWOOD, Fla. (AP) — Nine people were injured when gunfire erupted along a beachside promenade in Hollywood, Florida, sending people frantically running for cover along the crowded beach on Memorial Day.', 'url': 'https://apnews.com/article/hollywood-florida-beach-shooting-93dda56246a69d8913f35349c52d83c5', 'urlToImage': 'https://storage.googleapis.com/afs-prod/media/0c50e988b8e240bc9f2ec68511e3a372/3000.webp', 'publishedAt': '2023-05-30T11:00:04Z', 'content': '9 injured in shooting near beach in Hollywood, FloridaHOLLYWOOD, Fla. (AP) — Nine people were injured when gunfire erupted along a beachside promenade in Hollywood, Florida, sending people franticall… [+3356 chars]'}, {'source': {'id': 'associated-press', 'name': 'Associated Press'}, 'author': 
policy AND (drug OR "affirmative action")) OR regulate OR regulation
# <class 'dict'>
# {'status': 'ok', 'totalResults': 0, 'articles': []}
# 40
# associated-press 2023-05-30 (policy AND (drug OR "affirmative action")) OR regulate OR regulation
# Source: the-hill
# Date: 2023-05-30
# Query word: gender OR male OR female OR transgender
# <class 'dict'>
# ...
# Source ID: the-hill
# Source name: The Hill
# Author: Emily Brooks
# Title: First Republican publicly supports ousting McCarthy as Speaker...
# URL: https://thehill.com/homenews/house/4026377-first-republican-publicly-supports-ousting-mccarthy-as-speaker/
# Publish date: 2023-05-30T18:25:37Z
# Article text: Skip to content
# Rep. Dan Bishop (R-N.C.) on Tuesday became the first Republican to publicly support ousting Speaker Kevin McCarthy (R-Calif.) over the debt ceiling deal he struck with President Bide… [+3475 chars]
#
# Source ID: the-hill
# Source name: The Hill
# Author: Julia Shapero
# Title: Gaetz: Passing debt deal without Republican majority would ‘likely trigger an immediate motion’ to oust McCarthy
# URL: https://thehill.com/homenews/house/4026850-gaetz-passing-debt-deal-without-republican-majority-would-likely-trigger-an-immediate-motion-to-oust-mccarthy/
# Publish date: 2023-05-30T21:57:07Z
# Article text: Rep. Matt Gaetz (R-Fla.) said on Tuesday that passing a debt deal without a Republican majority in the House would trigger an immediate motion to oust Speaker Kevin McCarthy (R-Calif.).
# If a majorit… [+1831 chars]
#
# Source ID: the-hill
# Source name: The Hill
# Author: Brett Samuels
# Title: Pence: ‘American people deserve better’ than debt ceiling deal
# URL: https://thehill.com/homenews/campaign/4026408-pence-debt-limit-deal-disapproval/
# Publish date: 2023-05-30T18:04:38Z
# Article text: Former Vice President Mike Pence, who is expected to launch a presidential campaign in the coming weeks, voiced his disapproval on Tuesday of a budget deal struck by the White House and House GOP lea… [+2016 chars]
#
# Source ID: the-hill
# Source name: The Hill
# Author: Jared Gans
# Title: Dina Powell McCormick leaving Goldman for merchant bank role
# URL: https://thehill.com/business/4026290-dina-powell-mccormick-leaving-goldman-for-merchant-bank-role/
# Publish date: 2023-05-30T16:42:53Z
# Article text: Skip to content
# A former Trump administration official is leaving her position as a top executive at Goldman Sachs to become a partner at the merchant bank BDT &amp; MSD Partners.
# A release Tuesda… [+1911 chars]
#
# Source ID: the-hill
# Source name: The Hill
# Author: Alexander Bolton
# Title: Paul proposes conservative alternative to Biden-McCarthy debt deal
# URL: https://thehill.com/policy/healthcare/4026311-paul-proposes-conservative-alternative-to-biden-mccarthy-debt-deal/
# Publish date: 2023-05-30T17:00:29Z
# Article text: Skip to content
# Sen. Rand Paul (R-Ky.), who says he will not vote for the debt limit deal struck over the weekend by President Biden and Speaker Kevin McCarthy (R-Calif.), is proposing that Congress… [+2697 chars]
#
# 49
# the-hill 2023-05-30 (political AND (bias OR party)) OR republican OR democrat OR election
# Query word: (policy AND (drug OR "affirmative action")) OR regulate OR regulation
# <class 'dict'>
# {'status': 'ok', 'totalResults': 0, 'articles': []}
# 49
# the-hill 2023-05-30 (policy AND (drug OR "affirmative action")) OR regulate OR regulation
# Source: reuters
# Date: 2023-05-30
# Query word: gender OR male OR female OR transgender
# <class 'dict'>
# {'status': 'ok', 'totalResults': 2, 'articles': [{'source': {'id': 'reuters', 'name': 'Reuters'}, 'author': 'Towleroad', 'title': 'Deepfaking it: America’s 2024 election collides with AI boom', 'description': 'Published by Reuters (Note: Strong language in paragraph 10) By Alexandra Ulmer and Anna Tong (Reuters) – “I actually like Ron DeSantis a lot,” Hillary Clinton reveals in a surprise online endorsement video. “He’s just the kind of guy this country needs, and …', 'url': 'http://rmb.reuters.com/rmd/rss/item/tag:reuters.com,2023:newsml_KBN2XL0IR:6?channel=FES376', 'urlToImage': 'https://www.towleroad.com/wp-content/uploads/2023/05/680079-origin_1.jpg', 'publishedAt': '2023-05-30T17:12:23Z', 'content': '(Note: Strong language in paragraph 10)\r\nBy Alexandra Ulmer and Anna Tong\r\n(Reuters) – “I actually like Ron DeSantis a lot,” Hillary Clinton reveals in a surprise online endorsement video. “He’s just… [+8032 chars]'}, {'source': {'id': 'reuters', 'name': 'Reuters'}, 'author': 'Towleroad', 'title': 'Japan court rules that a bar on same-sex marriage is unconstitutional', 'description': 'Published by Reuters By Elaine Lies TOKYO (Reuters) – A Japanese court ruled on Tuesday that not allowing same-sex marriage was unconstitutional, a decision activists welcomed as a step towards marriage equality in the only Group of Seven nation with no legal…', 'url': 'http://rmb.reuters.com/rmd/rss/item/tag:reuters.com,2023:newsml_KBN2XL07G:9?channel=FES376', 'urlToImage': 'https://www.towleroad.com/wp-content/uploads/2023/05/680103-origin_1.jpg', 'publishedAt': '2023-05-30T17:13:28Z', 'content': 'By Elaine Lies\r\nTOKYO (Reuters) – A Japanese court ruled on Tuesday that not allowing same-sex marriage was unconstitutional, a decision activists welcomed as a step towards marriage equality in the … [+3399 chars]'}]}
# Source ID: reuters
# Source name: Reuters
# Author: Towleroad
# Title: Deepfaking it: America’s 2024 election collides with AI boom
# URL: http://rmb.reuters.com/rmd/rss/item/tag:reuters.com,2023:newsml_KBN2XL0IR:6?channel=FES376
# Publish date: 2023-05-30T17:12:23Z
# Article text: (Note: Strong language in paragraph 10)
# By Alexandra Ulmer and Anna Tong
# (Reuters) – “I actually like Ron DeSantis a lot,” Hillary Clinton reveals in a surprise online endorsement video. “He’s just… [+8032 chars]
#
# Source ID: reuters
# Source name: Reuters
# Author: Towleroad
# Title: Japan court rules that a bar on same-sex marriage is unconstitutional
# URL: http://rmb.reuters.com/rmd/rss/item/tag:reuters.com,2023:newsml_KBN2XL07G:9?channel=FES376
# Publish date: 2023-05-30T17:13:28Z
# Article text: By Elaine Lies
# TOKYO (Reuters) – A Japanese court ruled on Tuesday that not allowing same-sex marriage was unconstitutional, a decision activists welcomed as a step towards marriage equality in the … [+3399 chars]
#
# 51
# reuters 2023-05-30 gender OR male OR female OR transgender
# Query word: security AND (social OR national)
# <class 'dict'>
# {'status': 'ok', 'totalResults': 1, 'articles': [{'source': {'id': 'reuters', 'name': 'Reuters'}, 'author': 'Towleroad', 'title': 'Blinken says US to consider visa restrictions over Ugandan anti-gay law', 'description': 'Published by Reuters WASHINGTON (Reuters) – U.S. Secretary of State Antony Blinken on Monday said his government would consider visa restrictions against Ugandan officials and others for the abuse of human rights following the implementation of one of the wor…', 'url': 'http://rmb.reuters.com/rmd/rss/item/tag:reuters.com,2023:newsml_KBN2XK0V4:3?channel=FES376', 'urlToImage': 'https://www.towleroad.com/wp-content/uploads/2023/05/680113-origin_1.jpg', 'publishedAt': '2023-05-30T17:13:45Z', 'content': 'WASHINGTON (Reuters) – U.S. Secretary of State Antony Blinken on Monday said his government would consider visa restrictions against Ugandan officials and others for the abuse of human rights followi… [+1778 chars]'}]}
# Source ID: reuters
# Source name: Reuters
# Author: Towleroad
# Title: Blinken says US to consider visa restrictions over Ugandan anti-gay law
# URL: http://rmb.reuters.com/rmd/rss/item/tag:reuters.com,2023:newsml_KBN2XK0V4:3?channel=FES376
# Publish date: 2023-05-30T17:13:45Z
# Article text: WASHINGTON (Reuters) – U.S. Secretary of State Antony Blinken on Monday said his government would consider visa restrictions against Ugandan officials and others for the abuse of human rights followi… [+1778 chars]
#
# 52
# reuters 2023-05-30 security AND (social OR national)
# Query word: justice OR surveillance
# <class 'dict'>
# {'status': 'ok', 'totalResults': 0, 'articles': []}
# 52
# reuters 2023-05-30 justice OR surveillance
# Query word: healthcare OR "health care"
# <class 'dict'>
# {'status': 'ok', 'totalResults': 0, 'articles': []}
# 52
# reuters 2023-05-30 healthcare OR "health care"
# Query word: (political AND (bias OR party)) OR republican OR democrat OR election
# <class 'dict'>
# {'status': 'ok', 'totalResults': 1, 'articles': [{'source': {'id': 'reuters', 'name': 'Reuters'}, 'author': 'Towleroad', 'title': 'Deepfaking it: America’s 2024 election collides with AI boom', 'description': 'Published by Reuters (Note: Strong language in paragraph 10) By Alexandra Ulmer and Anna Tong (Reuters) – “I actually like Ron DeSantis a lot,” Hillary Clinton reveals in a surprise online endorsement video. “He’s just the kind of guy this country needs, and …', 'url': 'http://rmb.reuters.com/rmd/rss/item/tag:reuters.com,2023:newsml_KBN2XL0IR:6?channel=FES376', 'urlToImage': 'https://www.towleroad.com/wp-content/uploads/2023/05/680079-origin_1.jpg', 'publishedAt': '2023-05-30T17:12:23Z', 'content': '(Note: Strong language in paragraph 10)\r\nBy Alexandra Ulmer and Anna Tong\r\n(Reuters) – “I actually like Ron DeSantis a lot,” Hillary Clinton reveals in a surprise online endorsement video. “He’s just… [+8032 chars]'}]}
# Source ID: reuters
# Source name: Reuters
# Author: Towleroad
# Title: Deepfaking it: America’s 2024 election collides with AI boom
# URL: http://rmb.reuters.com/rmd/rss/item/tag:reuters.com,2023:newsml_KBN2XL0IR:6?channel=FES376
# Publish date: 2023-05-30T17:12:23Z
# Article text: (Note: Strong language in paragraph 10)
# By Alexandra Ulmer and Anna Tong
# (Reuters) – “I actually like Ron DeSantis a lot,” Hillary Clinton reveals in a surprise online endorsement video. “He’s just… [+8032 chars]
#
# 53
# reuters 2023-05-30 (political AND (bias OR party)) OR republican OR democrat OR election
# Query word: (policy AND (drug OR "affirmative action")) OR regulate OR regulation
# <class 'dict'>
# {'status': 'ok', 'totalResults': 1, 'articles': [{'source': {'id': 'reuters', 'name': 'Reuters'}, 'author': 'Towleroad', 'title': 'Deepfaking it: America’s 2024 election collides with AI boom', 'description': 'Published by Reuters (Note: Strong language in paragraph 10) By Alexandra Ulmer and Anna Tong (Reuters) – “I actually like Ron DeSantis a lot,” Hillary Clinton reveals in a surprise online endorsement video. “He’s just the kind of guy this country needs, and …', 'url': 'http://rmb.reuters.com/rmd/rss/item/tag:reuters.com,2023:newsml_KBN2XL0IR:6?channel=FES376', 'urlToImage': 'https://www.towleroad.com/wp-content/uploads/2023/05/680079-origin_1.jpg', 'publishedAt': '2023-05-30T17:12:23Z', 'content': '(Note: Strong language in paragraph 10)\r\nBy Alexandra Ulmer and Anna Tong\r\n(Reuters) – “I actually like Ron DeSantis a lot,” Hillary Clinton reveals in a surprise online endorsement video. “He’s just… [+8032 chars]'}]}
# Source ID: reuters
# Source name: Reuters
# Author: Towleroad
# Title: Deepfaking it: America’s 2024 election collides with AI boom
# URL: http://rmb.reuters.com/rmd/rss/item/tag:reuters.com,2023:newsml_KBN2XL0IR:6?channel=FES376
# Publish date: 2023-05-30T17:12:23Z
# Article text: (Note: Strong language in paragraph 10)
# By Alexandra Ulmer and Anna Tong
# (Reuters) – “I actually like Ron DeSantis a lot,” Hillary Clinton reveals in a surprise online endorsement video. “He’s just… [+8032 chars]
#
# 54
# reuters 2023-05-30 (policy AND (drug OR "affirmative action")) OR regulate OR regulation
# [('BBC News', 'https://www.facebook.com/bbcnews', "India's protesting wrestlers to sink medals in Ganges", 'https://www.bbc.co.uk/news/world-asia-india-65751102', '2023-05-30T09:28:31Z', "India's top wrestlers have said they will throw their medals in the Ganges, the country's holiest river, as part of their ongoing months-long protest.\r\nThey also plan to go on an indefinite hunger st… [+2706 chars]"), ('BBC News', None, 'The tennis generation that changed the world', 'https://www.bbc.co.uk/sport/tennis/65501241', '2023-05-30T11:06:53Z', 'The new BBC series tells the story of a golden era for tennis\r\n<table>\r\n<tr><td>Watch Gods of Tennis on on BBC Two on Sunday, 4 June at 21:00 GMT and on BBC iPlayer.</td></tr>\r\n</table>A new BBC docu… [+4921 chars]'), ('BBC News', 'https://www.facebook.com/bbcnews', "Iran tries female journalists who reported on Mahsa Amini's death", 'https://www.bbc.co.uk/news/world-middle-east-65753525', '2023-05-30T13:48:10Z', "Two Iranian female journalists who helped break the story of Mahsa Amini's death in custody in September have gone on trial before a Revolutionary Court.\r\nNiloufar Hamedi and Elaheh Mohammadi have be… [+3566 chars]"), ('BBC News', 'https://www.facebook.com/bbcnews', "Kathleen Stock: Gender-critical academic 'determined' to do talk", 'https://www.bbc.co.uk/news/education-65714821', '2023-05-30T09:25:00Z', 'A gender-critical academic says she is "determined" to speak at the Oxford Union after some students responded angrily to her invitation to a talk.\r\nThere has been a row over whether Prof Kathleen St… [+4788 chars]'), ('BBC News', 'https://www.facebook.com/bbcnews', 'Police Scotland officers fear being targeted for calling out sexism', 'https://www.bbc.co.uk/news/uk-scotland-65757862', '2023-05-30T21:47:25Z', 'Police Scotland officers who raise concerns about sexism and misogyny feel they have a "target on their back", a new report has found.\r\nIt also highlights previously expressed fears that a "boys\' clu… [+4453 chars]'), ('BBC News', 'https://www.facebook.com/bbcnews', 'Wolverhampton police hunt murder suspect as two arrested', 'https://www.bbc.co.uk/news/uk-england-birmingham-65756614', '2023-05-30T12:53:03Z', 'Police are hunting a 25-year-old man wanted on suspicion of a murder in Wolverhampton.\r\nThe deceased, a 48-year-old male, was found with serious head injuries on Tettenhall Road at about 07:00 BST on… [+999 chars]'), ('BBC News', None, 'Sue Redfern: Umpire becomes first woman to stand in T20 Blast', 'https://www.bbc.co.uk/sport/cricket/65757349', '2023-05-30T13:44:58Z', "Umpire Sue Redfern worked at the ICC Women's T20 World Cup earlier this year\r\nSue Redfern will become the first woman to stand as an on-field umpire in the T20 Blast when Gloucestershire host Middles… [+1422 chars]"), ('BBC News', 'https://www.facebook.com/bbcnews', 'Glastonbur: Rick Astley and Queens of the Stone Age added to line-up', 'https://www.bbc.co.uk/news/entertainment-arts-65755115', '2023-05-30T11:12:36Z', "Queens Of The Stone Age and Rick Astley are among the artists who've been added to this year's Glastonbury festival, as organisers unveil the final line-up.\r\nQueens Of The Stone Age top the bill on T… [+3410 chars]"), ('BBC News', 'https://www.facebook.com/bbcnews', "Phillip Schofield dropped as Prince's Trust ambassador", 'https://www.bbc.co.uk/news/entertainment-arts-65761305', '2023-05-30T18:48:12Z', "The Prince's Trust has dropped Phillip Schofield as an ambassador after he admitted he had an affair with a young male colleague and lied to cover it up.\r\nThe charity, founded by the King, said it wa… [+436 chars]"), ('BBC News', 'https://www.facebook.com/bbcnews', 'Myanmar coup: The soldiers refusing to fight', 'https://www.bbc.co.uk/news/world-asia-65743887', '2023-05-30T21:22:50Z', 'The Myanmar military is suffering defections from its forces and is finding it hard to recruit. In exclusive interviews, newly-defected soldiers tell the BBC that the junta, who seized  ...
# 54

# %%
#api_record_lst01 = [(1, 1, 1), (2, 2, 2), (3, 3, 3), (1, 1, 1), (4, 4, 4), (3, 3, 3)]
#print(api_record_lst01)
api_record_set01 = set(api_record_lst01)
print(api_record_set01)
api_record_lst02 = list(api_record_set01)
print(api_record_lst02)
print(len(api_record_lst02))
# Out:
# {('Associated Press', 'ap news', 'Crucial days ahead for debt ceiling deal...', 'https://apnews.com/article/debt-limit-biden-mccarthy-house-votes-c8484d7fcd1e38fa593e5dc79c910747', '2023-05-30T13:00:04Z', 'Crucial days ahead as debt ceiling deal goes for vote and Biden calls lawmakers for supportWASHINGTON (AP) — President Joe Biden says he “feels good” about the debt ceiling and budget deal negotiated… [+6256 chars]'), ('Reuters', 'Towleroad', 'Japan court rules that a bar on same-sex marriage is unconstitutional', 'http://rmb.reuters.com/rmd/rss/item/tag:reuters.com,2023:newsml_KBN2X
# 43

# %% [markdown]
# ## Initiate MySQL connection

# %%
'''Set local environment variables to hide user name & password citation:
https://www.geeksforgeeks.org/how-to-hide-sensitive-credentials-using-python/'''

user_name = os.environ['MySQLUSRAC']
user_pass = os.environ['MySQLPWDAC']

# Instantiate connection
db_conn = mysql.connect(host='localhost',
                        port=int(3306),
                        user=user_name,
                        passwd=user_pass,
                        db='509_final_proj')

# Create a cursor object
cursor = db_conn.cursor()

# %%
tbl_names = pd.read_sql('SHOW TABLES', db_conn)

display(tbl_names)
print(type(tbl_names))
# Out:
# /Users/davidfriesen/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   Tables_in_509_final_proj
# 0                 nar_temp
# 1            news_articles
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Establish logging policy

# %%
'''Logging citations (see additional code in following code blocks:
OpenAI. (2021). ChatGPT [Computer software]. https://openai.com/;
https://docs.python.org/3/howto/logging.html#logging-basic-example;
https://docs.python.org/3/howto/logging.html#logging-to-a-file;
https://docs.python.org/3/howto/logging-cookbook.html#using-a-rotating-log-file-handler;
https://docs.python.org/3/howto/logging-cookbook.html#using-a-timed-rotating-file-handler'''

# Set up logging
logging.basicConfig(level=logging.INFO,
                    filename='pymysql.log',
                    filemode='a',
                    format='>>>>>>>>>>>>>><<<<<<<<<<<<<<\n%(asctime)s - %(levelname)s - %(message)s')

# %% [markdown]
# ### Update individual tables

# %% [markdown]
# #### Update `news_articles` table from API

# %%
nat_tbl_name = 'nar_temp'
nwa_tbl_name = 'news_articles'

# %%
'''Using cursor and loading into temp file:
OpenAI. (2021). ChatGPT [Computer software]. https://openai.com/;
https://pynative.com/python-mysql-insert-data-into-database-table/'''

# Execute query and measure execution time
start_time = time.time()

# Wipe temp table
try:
    nat_dlt_tble_stmnt = f"""DELETE FROM {nat_tbl_name}"""
    cursor.execute(nat_dlt_tble_stmnt)
    logging.info(f'Successfully executed query:\n{nat_dlt_tble_stmnt}\n\nRecords scanned: {cursor.rowcount}')
except mysql.Error as e:
    logging.error(f'Error executing query:\n{nat_dlt_tble_stmnt}\n\n{e}')
finally:
    end_time = time.time()
    logging.info(f'Time taken: {end_time - start_time:.3f} seconds\n>>>>>>>>>>>>>><<<<<<<<<<<<<<\n\n')

# Execute query and measure execution time
start_time = time.time()

# Load data from CSV file into a temporary table
try:
    nat_csv_load_stmnt = f"""
    INSERT INTO {nat_tbl_name}
    (
    source_name,
    author,
    title,
    url,
    publish_date,
    content
    )
    VALUES (%s, %s, %s, %s, %s, %s)
    """

    # Execute the query with multiple values
    cursor.executemany(nat_csv_load_stmnt, api_record_lst02)
    #cursor.execute(nat_csv_load_stmnt)
    logging.info(f'Successfully executed query:\n{nat_csv_load_stmnt}\n\nRecords scanned: {cursor.rowcount}')
except mysql.Error as e:
    logging.error(f'Error executing query:\n{nat_csv_load_stmnt}\n\n{e}')
finally:
    end_time = time.time()
    logging.info(f'Time taken: {end_time - start_time:.3f} seconds\n>>>>>>>>>>>>>><<<<<<<<<<<<<<\n\n')

# Execute query and measure execution time
start_time = time.time()

# Insert new records into main table
try:
    nwa_load_stmnt = f"""
    INSERT INTO {nwa_tbl_name}
    (
    source_name,
    author,
    title,
    url,
    publish_date,
    content
    )
    SELECT
        tp.source_name,
        tp.author,
        tp.title,
        tp.url,
        tp.publish_date,
        tp.content
    FROM {nat_tbl_name} AS tp
    LEFT JOIN {nwa_tbl_name} AS mn
        ON tp.title = mn.title
            AND CAST(LEFT(tp.publish_date, 10) AS DATE) = CAST(LEFT(mn.publish_date, 10) AS DATE)
            AND tp.author = mn.author
    """
    cursor.execute(nwa_load_stmnt)
    logging.info(f'Successfully executed query:\n{nwa_load_stmnt}\n\nRecords scanned: {cursor.rowcount}')
except mysql.Error as e:
    logging.error(f'Error executing query:\n{nwa_load_stmnt}\n\n{e}')
finally:
    end_time = time.time()
    logging.info(f'Time taken: {end_time - start_time:.3f} seconds\n>>>>>>>>>>>>>><<<<<<<<<<<<<<\n\n')

# Execute query and measure execution time
start_time = time.time()

# Wipe temp table
try:
    cursor.execute(nat_dlt_tble_stmnt)
    logging.info(f'Successfully executed query:\n{nat_dlt_tble_stmnt}\n\nRecords scanned: {cursor.rowcount}')
except mysql.Error as e:
    logging.error(f'Error executing query:\n{nat_dlt_tble_stmnt}\n\n{e}')
finally:
    end_time = time.time()
    logging.info(f'Time taken: {end_time - start_time:.3f} seconds\n>>>>>>>>>>>>>><<<<<<<<<<<<<<\n\n')

# %% [markdown]
# ### Commit changes and close cursor and connection instances

# %%
# Commit the changes to the database
db_conn.commit()

# Close the cursor and database connection
cursor.close()
db_conn.close()

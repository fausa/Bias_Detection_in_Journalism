# %% [markdown]
# # 509 Final Project

# %% [markdown]
# ## Rsolve dependencies

# %%
! pip install newsapi-python
# Out:
# Requirement already satisfied: newsapi-python in c:\users\acarr\anaconda3\envs\tf-py38-v1\lib\site-packages (0.2.7)
# Requirement already satisfied: requests<3.0.0 in c:\users\acarr\anaconda3\envs\tf-py38-v1\lib\site-packages (from newsapi-python) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\acarr\anaconda3\envs\tf-py38-v1\lib\site-packages (from requests<3.0.0->newsapi-python) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acarr\anaconda3\envs\tf-py38-v1\lib\site-packages (from requests<3.0.0->newsapi-python) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acarr\anaconda3\envs\tf-py38-v1\lib\site-packages (from requests<3.0.0->newsapi-python) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\acarr\anaconda3\envs\tf-py38-v1\lib\site-packages (from requests<3.0.0->newsapi-python) (1.26.15)

# %% [markdown]
# ## Globally import libraries

# %%
import numpy as np
import pandas as pd
import pymysql as mysql
import matplotlib.pyplot as plt
import os
import shutil
import re
import logging
import time
import zipfile
import requests
from bs4 import BeautifulSoup
import datetime
import re
import regex as rex
from collections import defaultdict, Counter
import random
#import mysql.connector

# Set pandas global options
pd.options.display.max_rows = 17

# %%
today = datetime.date.today()
print(today)
print(type(today))
# Out:
# 2023-06-02
# <class 'datetime.date'>

# %% [markdown]
# ## Connect to NewsAPI client

# %%
from newsapi import NewsApiClient

api_key = os.environ['NewsAPIKey']

# Init
newsapi = NewsApiClient(api_key=api_key)

# %% [markdown]
# ## Pull article info from API

# %% [markdown]
# # /v2/top-headlines/sources
# sources = newsapi.get_sources()
# print(sources)

# %%
def news_api_urls(q=None,
                  s=None,
                  d_from='2023-05-01',
                  d_to='2023-05-31',
                  api_lst=[]):
    all_articles = newsapi.get_everything(q=q,
                                          sources=s,
                                          from_param=d_from,
                                          to=d_to,
                                          language='en',
                                          sort_by='relevancy',
                                          page=1)

    print(type(all_articles))
    print(all_articles)
    #print('Article list: ', all_articles['articles'])
    for article in all_articles['articles']:
        print('Source ID:', article['source']['id'])
        print('Source name:', article['source']['name'])
        print('Author:', article['author'])
        print('Title:', article['title'])
        print('URL:', article['url'])
        print('Publish date:', article['publishedAt'])
        print('Article text:', article['content'], '\n')

    # Create a list of tuples from the dictionary data
    source_data01 = [(a['source']['name'],
                      a['author'],
                      a['title'],
                      a['url'],
                      a['publishedAt'],
                      a['content'])
                     for a in all_articles['articles']]

    api_lst.extend(source_data01)
    #print(api_lst)
    print(len(api_lst))

# %% [markdown]
# ## Connect to API to access URLs

# %% [markdown]
# ### Set API filter parameters

# %%
# Citation comes from Allsides Media Bias Chart
#source_lst = ['cnn', 'reuters', 'fox-news']
#source_lst = ['cnn', 'newsweek', 'fox-news']
source_lst = ['newsweek']

#date_lst = ['2023-06-01', '2023-05-31']
#date_lst = ['2023-05-30', '2023-05-29']
date_lst = ['2023-05-30']

# Comes from academci text (fill in citation from DF)
q_word_lst = ['gender OR male OR female OR transgender', 'security AND (social OR national)',
              'justice OR surveillance', 'healthcare OR "health care"',
              '(political AND (bias OR party)) OR republican OR democrat OR election', '(policy AND (drug OR "affirmative action")) OR regulate OR regulation']

# %% [markdown]
# ### Access API

# %%
api_record_lst01 = []
for s in source_lst:
    print(f'Source: {s}')
    for d in date_lst:
        print(f'Date: {d}')
        for q in q_word_lst:
            print(f'Query word: {q}')
            time.sleep(5 + 11 * random.random())
            news_api_urls(q=q,
                          s=s,
                          d_from=d,
                          d_to=d,
                          api_lst=api_record_lst01)
            print(s, d, q)
    time.sleep(10 + 13 * random.random())

print(api_record_lst01)
print(len(api_record_lst01))
# Out:
# Source: newsweek
# Date: 2023-05-30
# Query word: gender OR male OR female OR transgender
# <class 'dict'>
# {'status': 'ok', 'totalResults': 15, 'articles': [{'source': {'id': 'newsweek', 'name': 'Newsweek'}, 'author': 'Jon Schweppe', 'title': 'Grassroots Boycotts Against Woke Corporations Are Working | Opinion', 'description': 'First Bud Light, now Target—corporations that tried to push transgender ideology on their customers have faced enormous backlash.', 'url': 'https://www.newsweek.com/grassroots-boycotts-against-woke-corporations-are-working-opinion-1803339', 'urlToImage': 'https://d.newsweek.com/en/full/2240738/target-store.jpg', 'publishedAt': '2023-05-30T17:05:49Z', 'content': "The sacrosanct month of Pride begins later this week. If you're a reasonable business executive sitting in a C-suite at a major American corporation, you've got to be asking yourself: is all of this … [+5589 chars]"}, {'source': {'id': 'newsweek', 'name': 'Newsweek'}, 'author': 'Ryan Smith', 'title': "LEGO Faces Boycott Calls Over 'Transgender Building Sets'", 'description': 'The toymaker has become the latest company to face furor for collaborating with and supporting the LGBTQ community.', 'url': 'https://www.newsweek.com/lego-faces-boycott-calls-over-transgender-building-sets-1803239', 'urlToImage': 'https://d.newsweek.com/en/full/2240438/lego-faces-boycott-calls-over-lgbtq-campaign.jpg', 'publishedAt': '2023-05-30T09:49:47Z', 'content': 'LEGO is the latest company facing boycott calls amid outrage over its A to Z of Awesome campaign, which supports the LGBTQ+ community.\r\nLast year, the LEGO Group announced the launch of its campaign … [+6199 chars]'}, {'source': {'id': 'newsweek', 'name': 'Newsweek'}, 'author': 'Aleks Phillips', 'title': "Miller Lite Sales Soared After 'Woke' Ad Sparked Boycott Calls", 'description': 'The beer brand has continued to see double-digit sales rises, even after facing a backlash over a recent marketing campaign.', 'url': 'https://www.newsweek.com/miller-lite-beer-sales-soar-woke-ad-boycott-1803364', 'urlToImage': 'https://d.newsweek.com/en/full/2240616/miller-lite-sign.jpg', 'publishedAt': '2023-05-30T16:10:03Z', 'content': 'Miller Lite has seen a steady increase in sales in the past two months, despite facing calls for a boycott over a supposedly "woke" advertising campaign for Women\'s History Month.\r\nAccording to data … [+3383 chars]'}, {'source': {'id': 'newsweek', 'name': 'Newsweek'}, 'author': 'Ryan Smith', 'title': 'Candace Owens Misgenders Dylan Mulvaney in Viral Message', 'description': '"Some of you guys did not understand the danger of a grown man like Dylan Mulvaney self-identifying as a little girl" tweeted Owens as she criticized Mulvaney.', 'url': 'https://www.newsweek.com/candace-owens-misgenders-dylan-mulvaney-viral-twitter-post-transgender-1803385', 'urlToImage': 'https://d.newsweek.com/en/full/2240633/candace-owens-criticizes-dylan-mulvaney.jpg', 'publishedAt': '2023-05-30T16:04:19Z', 'content': 'Candace Owens has misgendered Dylan Mulvaney in a social media post criticizing the transgender TikTok star.\r\nOver the past several weeks, social media influencer Mulvaney, 26, has been the focus of … [+4462 chars]'}, {'source': {'id': 'newsweek', 'name': 'Newsweek'}, 'author': None, 'title': 'What Consumers and Companies Should Know About "Clinically Proven" Claims', 'description': "Newsweek Executive Forum member Dr. Jeff Chen, founder of Radicle Science, explains that some supplement companies have been getting away with making misleading product efficacy claims. But that won't be true for much longer.", 'url': 'https://www.newsweek.com/what-consumers-companies-should-know-about-clinically-proven-claims-1802632', 'urlToImage': 'https://d.newsweek.com/en/full/2239330/jeff-chen.jpg', 'publishedAt': '2023-05-30T13:31:11Z', 'content': "When consumers go into a drugstore's supplements and vitamins aisle, choosing a product can be overwhelming. In the sea of bottles, how can you find one that works better than a placebo? To cut throu… [+6520 chars]"}, {'source': {'id': 'newsweek', 'name': 'Newsweek'}, 
source': {'id': 'newsweek', 'name': 'Newsweek'}, 'author': None, 'title': 'Building a Security Culture for Remote Employees', 'description': 'When it comes to building a security culture—whether on-site, remotely or in a hybrid manner—no company or employee is entirely free from risk.', 'url': 'https://www.newsweek.com/building-security-culture-remote-employees-1802907', 'urlToImage': 'https://d.newsweek.com/en/full/2239866/working-laptop.jpg', 'publishedAt': '2023-05-30T15:30:25Z', 'content': "According to The Hill, almost 30% of all work in January 2023 took place from employees' homes—six times as much as in 2019, based on data from WFH Research. In larger urban settings, this percentage… [+5724 chars]"}, {'source': {'id': 'newsweek', 'name': 'Newsweek'}, 'author': 'Ellie Cook', 'title': 'Ukraine Puts Number on F-16s After German Leopard Tank Success', 'description': 'Several countries, including the U.S., have committed to training Ukrainian pilots on F-16 fighter jets.', 'url': 'https://www.newsweek.com/ukraine-f16-fighter-jets-german-leopard-tank-arrival-oleksii-reznikov-1803227', 'urlToImage': 'https://d.newsweek.com/en/full/2240395/f-16c-fighting-falcon.jpg', 'publishedAt': '2023-05-30T09:21:38Z', 'content': "Ukraine needs around 100 Western fighter jets, Kyiv's defense minister has said, as a host of Western Leopard tanks arrives in Ukraine.\r\nMost of the 100 advanced aircraft should be F-16s, Ukrainian D… [+3705 chars]"}, {'source': {'id': 'newsweek', 'name': 'Newsweek'}, 'author': None, 'title': 'The Cloud Revolution in Marketing', 'description': 'Despite the invaluable benefits of adopting cloud computing to enrich marketing efforts, there are important considerations one must bear in mind when deploying.', 'url': 'https://www.newsweek.com/cloud-revolution-marketing-1802918', 'urlToImage': 'https://d.newsweek.com/en/full/2239879/conference-room.jpg', 'publishedAt': '2023-05-30T16:00:34Z', 'content': 'Like every facet of life, marketing evolves with technology—and nothing typifies recent shifts more aptly than the ongoing cloud revolution. While traditional marketing strategies, such as print ads,… [+7044 chars]'}, {'source': {'id': 'newsweek', 'name': 'Newsweek'}, 'author': 'Isabel van Brugen', 'title': "Lukashenko's Nuclear Weapons Offer Rejected by Russia's Neighbor", 'description': 'Belarusian President Alexander Lukashenko said if nations wanted to join a pact with Russia and Belarus, there could be "nuclear weapons for everyone."', 'url': 'https://www.newsweek.com/lukashenko-belarus-nuclear-weapons-offer-kazakhstan-russia-tokayev-1803269', 'urlToImage': 'https://d.newsweek.com/en/full/2240480/kazakh-president-kassym-jomart-tokayev-vladimir-putin.jpg', 'publishedAt': '2023-05-30T11:42:59Z', 'content': 'Kazakhstan President Kassym-Jomart Tokayev has rejected his Belarusian counterpart\'s proposal to join the Russia-Belarus "Union State," calling the offer a "joke."\r\nThe developments come after Belaru… [+3531 chars]'}, {'source': {'id': 'newsweek', 'name': 'Newsweek'}, 'author': 'Nick Reynolds', 'title': 'Joe Biden Rewards Donors With Admin Positions in Broken Promise to Voters', 'description': 'Biden once pledged to ensure only the "best people possible" would serve as U.S. ambassadors abroad. A new study argues that\'s not the case.', 'url': 'https://www.newsweek.com/joe-biden-rewards-donors-admin-positions-broken-promise-voters-1803442', 'urlToImage': 'https://d.newsweek.com/en/full/2240776/biden-breaks-ambassador-promise.jpg', 'publishedAt': '2023-05-30T20:19:33Z', 'content': 'It was an unspoken deal for generations of presidential hopefuls. A well-connected person helps get you elected, and in return, you make that person an ambassador somewhere exotic as a token of your … [+6789 chars]'}, {'source': {'id': 'newsweek', 'name': 'Newsweek'}, 'author': 
source': {'id': 'newsweek', 'name': 'Newsweek'}, 'author': None, 'title': 'How Mental Health Services Can Improve the Patient and Employee Experience', 'description': 'To reach optimal patient outcomes, health care leaders should be committed to both the patient and employee experiences.', 'url': 'https://www.newsweek.com/how-mental-health-services-can-improve-patient-employee-experience-1802491', 'urlToImage': 'https://d.newsweek.com/en/full/2239050/doctor-discussing-treatment.jpg', 'publishedAt': '2023-05-30T13:00:52Z', 'content': "Medical treatments can disrupt a person's emotional and mental well-being. The fear of the unknown, concerns about test results, financial accessibility to care, and medication side effects can ampli… [+6438 chars]"}, {'source': {'id': 'newsweek', 'name': 'Newsweek'}, 'author': 'Sophie Lloyd', 'title': 'Fitness Coach Drops 20lbs After Ditching Her Exercise Routine', 'description': 'Burned out after years of restricting food and punishing exercise regimes, body confidence coach Giulia Halkier decided to ditch the diets—and shed pounds.', 'url': 'https://www.newsweek.com/healthy-lifestyle-changes-weight-loss-confidence-coach-1800843', 'urlToImage': 'https://d.newsweek.com/en/full/2238376/giulia-hawker-before-after-weight-loss.jpg', 'publishedAt': '2023-05-30T13:15:41Z', 'content': 'While it\'s tempting to opt for a quick fix when it comes to achieving your "ideal" body, there are healthier and more sustainable methods for losing weight—no calorie counting or punishing exercise r… [+8481 chars]'}]}
# Source ID: newsweek
# Source name: Newsweek
# Author: None
# Title: How Mental Health Services Can Improve the Patient and Employee Experience
# URL: https://www.newsweek.com/how-mental-health-services-can-improve-patient-employee-experience-1802491
# Publish date: 2023-05-30T13:00:52Z
# Article text: Medical treatments can disrupt a person's emotional and mental well-being. The fear of the unknown, concerns about test results, financial accessibility to care, and medication side effects can ampli… [+6438 chars]
#
# Source ID: newsweek
# Source name: Newsweek
# Author: Sophie Lloyd
# Title: Fitness Coach Drops 20lbs After Ditching Her Exercise Routine
# URL: https://www.newsweek.com/healthy-lifestyle-changes-weight-loss-confidence-coach-1800843
# Publish date: 2023-05-30T13:15:41Z
# Article text: While it's tempting to opt for a quick fix when it comes to achieving your "ideal" body, there are healthier and more sustainable methods for losing weight—no calorie counting or punishing exercise r… [+8481 chars]
#
# 32
# newsweek 2023-05-30 healthcare OR "health care"
# Query word: (political AND (bias OR party)) OR republican OR democrat OR election
# <class 'dict'>
# {'status': 'ok', 'totalResults': 25, 'articles': [{'source': {'id': 'newsweek', 'name': 'Newsweek'}, 'author': 'Andrew Stanton', 'title': 'Joe Manchin Trails GOP Challenger by 22 Points in Key Senate Race: Poll', 'description': 'An East Carolina University poll of 957 registered voters showed how Senator Joe Manchin is faring against West Virginia Governor Jim Justice.', 'url': 'https://www.newsweek.com/joe-manchin-trails-gop-challenger-22-points-key-senate-race-poll-1803398', 'urlToImage': 'https://d.newsweek.com/en/full/2240672/joe-manchin-trails-gop-challenger.jpg', 'publishedAt': '2023-05-30T17:30:36Z', 'content': "West Virginia Senator Joe Manchin is trailing GOP challenger Governor Jim Justice by 22 points in a new poll, a troubling sign for Democrats hoping to keep control of the Senate in next year's electi… [+3231 chars]"}, {'source': {'id': 'newsweek', 'name': 'Newsweek'}, 'author': '
ynolds', 'Former Trump Official Is Building a Legal Case Against Bud Light', 'https://www.newsweek.com/former-trump-official-building-legal-case-agaisnt-bud-light-1803413', '2023-05-30T17:24:56Z', "A former top advisor to former President Donald Trump is gearing up to sue Bud Light's parent company (as well as a number of other brands) for allegedly tanking their shareholder value through the m… [+5640 chars]"), ('Newsweek', 'Ryan Smith', "Dylan Mulvaney Says She's Been 'Followed' For Months Amid Bud Light Furor", 'https://www.newsweek.com/dylan-mulvaney-says-has-been-followed-months-amid-bud-light-fiasco-1803309', '2023-05-30T13:29:18Z', 'TikTok star Dylan Mulvaney has revealed that she has been "followed on and off" over the past two months amid the ongoing furor over her Bud Light collaboration.\r\nOn April 1, the transgender influenc… [+3955 chars]'), ('Newsweek', 'Aleks Phillips', 'Bud Light Sales Drop 29.5 Percent in Latest Week Since Boycott Calls', 'https://www.newsweek.com/bud-light-sales-decline-dylan-mulvaney-boycott-latest-1803292', '2023-05-30T11:27:09Z', 'Bud Light has continued to suffer declining fortunes as a boycott of the beer brand over its partnership with transgender influencer Dylan Mulvaney is reported to have had a lasting impact on its sal… [+3392 chars]'), ('Newsweek', 'Anna Skinner', 'High School Uses COVID Funds for Pride Drag Show Performance', 'https://www.newsweek.com/high-school-uses-covid-funds-pride-drag-show-performance-1803389', '2023-05-30T16:49:43Z', 'A Manchester, New Hampshire, high school is using $4,000 in leftover American Rescue Plan funds for a Pride event that includes drag show performers.\r\nThe event will celebrate Pride Month on June 2 a… [+3959 chars]'), ('Newsweek', 'James Crawford-Smith', "Meghan Markle's Reaction to Fl ...
# 58

# %%
#api_record_lst01 = [(1, 1, 1), (2, 2, 2), (3, 3, 3), (1, 1, 1), (4, 4, 4), (3, 3, 3)]
#print(api_record_lst01)
api_record_set01 = set(api_record_lst01)
print(api_record_set01)
api_record_lst02 = list(api_record_set01)
print(api_record_lst02)
print(len(api_record_lst02))
# Out:
# {('Newsweek', 'Robyn White', "Sheriff's Video Shows Rescue of Bear Stuck in Car at Lake Tahoe", 'https://www.newsweek.com/video-bear-car-lake-tahoe-1803237', '2023-05-30T08:54:56Z', "A police officer has been filmed saving a bear that got stuck inside a car at Lake Tahoe.\r\nThe Washoe County Sheriff's Office arrived after a resident found the animal sitting on the back seats of th… [+2693 chars]"), ('Newsweek', 'Anders Anglesey', 'Remains of Woman Missing for 12 Years Discovered at Rural Property: Police', 'https://www.newsweek.com/remains-woman-missing-12-years-discovered-rural-property-1803264', '2023-05-30T11:13:52Z', 'The remains of a Canadian woman missing for 12 years have been found at a rural property, according to police.\r\nThe Royal Canadian Mounted Police (RCMP) have identified remains found in east Vanderho… [+2572 chars]'), ('Newsweek', 'Brendan Cole', "Russian Lawmaker Leads Call to 'Cleanse' Ukraine and Its Language", 'https://www.newsweek.com/russia-ukraine-lpdr-ukrainian-cleanse-language-1803261', '2023-05-30T11:21:50Z', 'A Russian member of parliament has said that he and his political party believed that Ukraine and its language had no right to exist.\r\nThe comments were made by Alexei Didenko during a conference on … [+3344 chars]'
https://www.geeksforgeeks.org/how-to-hide-sensitive-credentials-using-python/'''

user_name = os.environ['MySQLUSRAC']
user_pass = os.environ['MySQLPWDAC']

# Instantiate connection
db_conn = mysql.connect(host='localhost',
                        port=int(3306),
                        user=user_name,
                        passwd=user_pass,
                        db='509_final_proj')

# Create a cursor object
cursor = db_conn.cursor()

# %%
tbl_names = pd.read_sql('SHOW TABLES', db_conn)

display(tbl_names)
print(type(tbl_names))
# Out:
# C:\Users\acarr\AppData\Local\Temp\ipykernel_3300\4193860975.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tbl_names = pd.read_sql('SHOW TABLES', db_conn)
#   Tables_in_509_final_proj
# 0                 nar_temp
# 1            news_articles
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Establish logging policy

# %%
'''Logging citations (see additional code in following code blocks:
OpenAI. (2021). ChatGPT [Computer software]. https://openai.com/;
https://docs.python.org/3/howto/logging.html#logging-basic-example;
https://docs.python.org/3/howto/logging.html#logging-to-a-file;
https://docs.python.org/3/howto/logging-cookbook.html#using-a-rotating-log-file-handler;
https://docs.python.org/3/howto/logging-cookbook.html#using-a-timed-rotating-file-handler'''

# Set up logging
logging.basicConfig(level=logging.INFO,
                    filename='pymysql.log',
                    filemode='a',
                    format='>>>>>>>>>>>>>><<<<<<<<<<<<<<\n%(asctime)s - %(levelname)s - %(message)s')

# %% [markdown]
# ### Update individual tables

# %% [markdown]
# #### Update `news_articles` table from API

# %%
nat_tbl_name = 'nar_temp'
nwa_tbl_name = 'news_articles'

# %%
'''Using cursor and loading into temp file:
OpenAI. (2021). ChatGPT [Computer software]. https://openai.com/;
https://pynative.com/python-mysql-insert-data-into-database-table/'''

# Execute query and measure execution time
start_time = time.time()

# Wipe temp table
try:
    nat_dlt_tble_stmnt = f"""DELETE FROM {nat_tbl_name}"""
    cursor.execute(nat_dlt_tble_stmnt)
    logging.info(f'Successfully executed query:\n{nat_dlt_tble_stmnt}\n\nRecords scanned: {cursor.rowcount}')
except mysql.Error as e:
    logging.error(f'Error executing query:\n{nat_dlt_tble_stmnt}\n\n{e}')
finally:
    end_time = time.time()
    logging.info(f'Time taken: {end_time - start_time:.3f} seconds\n>>>>>>>>>>>>>><<<<<<<<<<<<<<\n\n')

# Execute query and measure execution time
start_time = time.time()

# Load data from CSV file into a temporary table
try:
    nat_csv_load_stmnt = f"""
    INSERT INTO {nat_tbl_name}
    (
    source_name,
    author,
    title,
    url,
    publish_date,
    content
    )
    VALUES (%s, %s, %s, %s, %s, %s)
    """

    # Execute the query with multiple values
    cursor.executemany(nat_csv_load_stmnt, api_record_lst02)
    #cursor.execute(nat_csv_load_stmnt)
    logging.info(f'Successfully executed query:\n{nat_csv_load_stmnt}\n\nRecords scanned: {cursor.rowcount}')
except mysql.Error as e:
    logging.error(f'Error executing query:\n{nat_csv_load_stmnt}\n\n{e}')
finally:
    end_time = time.time()
    logging.info(f'Time taken: {end_time - start_time:.3f} seconds\n>>>>>>>>>>>>>><<<<<<<<<<<<<<\n\n')

# Execute query and measure execution time
start_time = time.time()

# Insert new records into main table
try:
    nwa_load_stmnt = f"""
    INSERT INTO {nwa_tbl_name}
    (
    source_name,
    author,
    title,
    url,
    publish_date,
    content
    )
    SELECT
        tp.source_name,
        tp.author,
        tp.title,
        tp.url,
        tp.publish_date,
        tp.content
    FROM {nat_tbl_name} AS tp
    LEFT JOIN {nwa_tbl_name} AS mn
        ON tp.title = mn.title
            AND CAST(LEFT(tp.publish_date, 10) AS DATE) = CAST(LEFT(mn.publish_date, 10) AS DATE)
            AND tp.author = mn.author
    """
    cursor.execute(nwa_load_stmnt)
    logging.info(f'Successfully executed query:\n{nwa_load_stmnt}\n\nRecords scanned: {cursor.rowcount}')
except mysql.Error as e:
    logging.error(f'Error executing query:\n{nwa_load_stmnt}\n\n{e}')
finally:
    end_time = time.time()
    logging.info(f'Time taken: {end_time - start_time:.3f} seconds\n>>>>>>>>>>>>>><<<<<<<<<<<<<<\n\n')

# Execute query and measure execution time
start_time = time.time()

# Wipe temp table
try:
    cursor.execute(nat_dlt_tble_stmnt)
    logging.info(f'Successfully executed query:\n{nat_dlt_tble_stmnt}\n\nRecords scanned: {cursor.rowcount}')
except mysql.Error as e:
    logging.error(f'Error executing query:\n{nat_dlt_tble_stmnt}\n\n{e}')
finally:
    end_time = time.time()
    logging.info(f'Time taken: {end_time - start_time:.3f} seconds\n>>>>>>>>>>>>>><<<<<<<<<<<<<<\n\n')

# %% [markdown]
# ### Commit changes and close cursor and connection instances

# %%
# Commit the changes to the database
db_conn.commit()

# Close the cursor and database connection
cursor.close()
db_conn.close()

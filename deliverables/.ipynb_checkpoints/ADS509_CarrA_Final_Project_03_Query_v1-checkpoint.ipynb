# %% [markdown]
# # 509 Final Project

# %% [markdown]
# ## Rsolve dependencies

# %% [markdown]
# ## Globally import libraries

# %%
import numpy as np
import pandas as pd
import pymysql as mysql
import matplotlib.pyplot as plt
import os
import shutil
import re
import logging
import time
import datetime as dt
import zipfile
import requests
from bs4 import BeautifulSoup
import datetime
import re
import regex as rex
from collections import defaultdict, Counter
import random
import json
#import mysql.connector

# Set pandas global options
pd.options.display.max_rows = 17

# %% [markdown]
# ## Upload data from CSV

# %%
'''Dir nav citation:
https://softhints.com/python-change-directory-parent/'''
curr_dir = os.path.abspath(os.curdir)
print(curr_dir)
os.chdir("..")
up1_dir = os.path.abspath(os.curdir)
print(up1_dir)
# Out:
# C:\Users\acarr\Documents\GitHub\ADS509_Final_project\deliverables
# C:\Users\acarr\Documents\GitHub\ADS509_Final_project

# %%
# change `data_location` to the location of the folder on your machine.
data_r_location = 'data_restricted'
data_location = 'data'

file_in_name = 'data_raw_amc.csv'
file_out_name = 'data_parsed_amc.csv'

file_in_path01 = os.path.join(up1_dir, data_r_location, file_in_name)
file_out_path = os.path.join(up1_dir, data_location, file_out_name)

print(f'CSV file in path: {file_in_path01}')
print(f'CSV file out path: {file_out_path}')
# Out:
# CSV file in path: C:\Users\acarr\Documents\GitHub\ADS509_Final_project\data_restricted\data_raw_amc.csv
# CSV file out path: C:\Users\acarr\Documents\GitHub\ADS509_Final_project\data\data_parsed_amc.csv

# %%
slct_tbl_full_df01 = pd.read_csv(file_in_path01)
display(slct_tbl_full_df01.head())
# Out:
#    text_id source_name                       author  \
# 0        1         CNN  Clare Foran,Nicky Robertson
# 1        2    Fox News             Paul Steinhauser
# 2        3    Fox News                  Greg Wehner
# 3        4    Fox News                 Michael Ruiz
# 4        5    Fox News               Brooke Singman
#
#                                                title  \
# 0  Senate races to avert default but vote timing ...
# 1  First on Fox: Pro-Tim Scott super PAC launches...
# 2  Pennsylvania bus driver allegedly used duct ta...
# 3  Bob Lee murder: Cash App founder seen with sus...
# 4  Senate GOP demands answers on security clearan...
#
#                                                  url          publish_date  \
# 0  https://www.cnn.com/2023/06/01/politics/senate...  2023-06-01T09:00:40Z
# 1  https://www.foxnews.com/politics/pro-scott-sup...  2023-06-01T16:12:56Z
# 2  https://www.foxnews.com/us/pennsylvania-bus-dr...  2023-05-31T00:21:20Z
# 3  https://www.foxnews.com/us/bob-lee-murder-cash...  2023-05-31T20:30:12Z
# 4  https://www.foxnews.com/politics/senate-gop-de...  2023-05-31T22:11:38Z
#
#                                         article_text content
# 0  <!DOCTYPE html>\n<html data-layout-uri="cms.cn...     NaN
# 1  <!DOCTYPE html>\n<html data-n-head="%7B%22lang...     NaN
# 2  <!DOCTYPE html>\n<html data-n-head="%7B%22lang...     NaN
# 3  <!DOCTYPE html>\n<html data-n-head="%7B%22lang...     NaN
# 4  <!DOCTYPE html>\n<html data-n-head="%7B%22lang...     NaN

# %%
count_nan = slct_tbl_full_df01['article_text'].isnull().sum()
 
# printing the number of values present
# in the column
print('Number of NaN values present: ' + str(count_nan))
# Out:
# Number of NaN values present: 0

# %%
slct_tbl_full_df02 = slct_tbl_full_df01.copy()
#slct_tbl_full_df02 = slct_tbl_full_df01.sort_values(by=['source_name'])
#slct_tbl_full_df02 = slct_tbl_full_df02.reset_index()

print(f'DF instances: {len(slct_tbl_full_df02)}')

slct_tbl_full_df02['article_parsed'] = ''

total_urls = len(slct_tbl_full_df02)

# Start timer
start_time = dt.datetime.today()

for i, row in enumerate(slct_tbl_full_df02.itertuples(), 1):
    #print(f'Enumeration #: {i}')
    #print(row[7])
    soup = BeautifulSoup(row[7], 'html.parser')

    try:
        script_tag = soup.find('script', {'type': 'application/ld+json'})
        if script_tag == None:
            print('\nJSON Object == None: Index:', i-1, '; source:',
                  row[2],
                  '; URL:', row[5])
        else:
            article_json = json.loads(script_tag.string)
            article_content = article_json['articleBody']
            slct_tbl_full_df02.at[row.Index, 'article_parsed'] = article_content

    except KeyError:
        print('\nMissing JSON key: Index:', i-1, '; source:',
              row[2],
              '; URL:', row[5])
        article_body = soup.find('div', class_='article__content-container')

        if article_body is None: #forfoxandbreitbert(sometimes)
            print('Class != article__content-container')
            article_body = soup.find('p', class_="speakable")
            if article_body is None: #breitbert(most)
                print('Class != speakable')
                article_body = soup.find('div', class_='entry-content')
                if article_body is None: #WashPost
                    print('Class != entry-content')
                    article_body = soup.find('div',class_='article-body')

        if article_body is not None:
            article_text = article_body.get_text()
            slct_tbl_full_df02.at[row.Index, 'article_parsed'] = article_text
        else:
            print('Could not parse')

    print('.', end='')
        
# End timer script
end_time = dt.datetime.today()
time_elapse = end_time - start_time
print(f'Start Time = {start_time}')
print(f'End Time = {end_time}')
print(f'Elapsed Time = {time_elapse}')
# Out:
# DF instances: 2929
# ................................................................
# Missing JSON key: Index: 64 ; source: CNN ; URL: https://www.cnn.com/politics/live-news/us-debt-ceiling-deadline-talks-05-31-23/index.html
# Class != article__content-container
# Class != speakable
# Class != entry-content
# Could not parse
# ..........
# JSON Object == None: Index: 74 ; source: Fox News ; URL: https://press.foxnews.com/2023/06/fox-news-channel-to-debut-new-weekend-primetime-lineup-on-june-3
# .............
# Missing JSON key: Index: 87 ; source: CNN ; URL: https://www.cnn.com/politics/live-news/us-debt-ceiling-senate-vote-06-01-23/index.html
# Class != article__content-container
# Class != speakable
# Class != entry-content
# Could not parse
# ........................................................................................................................................................................
# JSON Object == None: Index: 255 ; source: CNN ; URL: https://view.newsletters.cnn.com/messages/1685581226387e748f0e9a1e2/raw
# ........................................................................................................................................................
# Missing JSON key: Index: 407 ; source: CNN ; URL: https://www.cnn.com/politics/live-news/us-debt-ceiling-deadline-talks-05-30-23/index.html
# Class != article__content-container
# Class != speakable
# Class != entry-content
# Could not parse
# ......................................................................................................................................
# JSON Object == None: Index: 541 ; source: Fox News ; URL: https://press.foxnews.com/2023/05/sen-joni-ernst-and-sen-jeanne-shaheen-to-participate-in-forum-live-on-fox-nation-from-edward-m-kennedy-institute
# .......................
# Missing JSON key: Index: 564 ; source: Breitbart News ; URL: https://www.breitbart.com/europe/2023/05/05/ukraine-delegate-punches-russian-in-face-at-economic-summit/
# Class != article__content-container
# Class != speakable
# .
# Missing JSON key: Index: 565 ; source: Breitbart News ; URL: https://www.breitbart.com/europe/2023/05/05/watch-progressive-lawmaker-stumbles-when-asked-what-a-woman-is/
# Class != article__content-container
# Class != speakable
# ....
# Missing JSON key: Index: 569 ; source: Breitbart News ; URL: https://www.breitbart.com/politics/2023/05/06/exclusive-ohio-republican-bernie-moreno-gop-establishment-targeting-me-because-im-trump-aligned/
# Class != article__content-container
# Class != speakable
# .......
# Missing JSON key: Index:

# Class != article__content-container
# Class != speakable
# .
# Missing JSON key: Index: 2821 ; source: Breitbart News ; URL: https://www.breitbart.com/entertainment/2023/05/13/megyn-kelly-says-come-fk-me-up-to-charlize-theron-after-oscar-winning-actress-vows-violence-against-transphobes/
# Class != article__content-container
# Class != speakable
# .....
# Missing JSON key: Index: 2826 ; source: Breitbart News ; URL: https://www.breitbart.com/politics/2023/05/13/exclusive-j-d-vance-trumps-cnn-town-hall-was-a-home-run/
# Class != article__content-container
# Class != speakable
# ....
# Missing JSON key: Index: 2830 ; source: Breitbart News ; URL: https://www.breitbart.com/latin-america/2023/05/16/poll-over-half-colombians-would-prefer-president-like-el-salvadors-nayib-bukele/
# Class != article__content-container
# Class != speakable
# .....
# Missing JSON key: Index: 2835 ; source: Breitbart News ; URL: https://www.breitbart.com/clips/2023/05/14/chris-christie-cnn-went-in-the-tank-to-get-trump-on/
# Class != article__content-container
# Class != speakable
# .........
# Missing JSON key: Index: 2844 ; source: Breitbart News ; URL: https://www.breitbart.com/politics/2023/05/16/desantis-backed-candidates-lose-jacksonville-mayors-race-kentucky-governors-race/
# Class != article__content-container
# ..............
# Missing JSON key: Index: 2858 ; source: Breitbart News ; URL: https://www.breitbart.com/politics/2023/05/15/elise-stefanik-durham-report-shows-criminal-abuse-power-obama-biden-white-house/
# Class != article__content-container
# Class != speakable
# ...
# Missing JSON key: Index: 2861 ; source: Breitbart News ; URL: https://www.breitbart.com/asia/2023/05/16/japanese-citizens-take-smiling-lessons-to-recover-from-three-years-of-masks/
# Class != article__content-container
# Class != speakable
# ....
# Missing JSON key: Index: 2865 ; source: Breitbart News ; URL: https://www.breitbart.com/social-justice/2023/05/17/pro-life-father-mark-houck-says-fbi-raid-traumatized-his-7-children/
# Class != article__content-container
# Class != speakable
# ............
# Missing JSON key: Index: 2877 ; source: Breitbart News ; URL: https://www.breitbart.com/politics/2023/05/13/exclusive-west-virginia-gov-jim-justice-i-am-only-person-who-can-beat-joe-manchin/
# Class != article__content-container
# Class != speakable
# ....
# Missing JSON key: Index: 2881 ; source: CNN ; URL: https://www.cnn.com/politics/live-news/biden-mccarthy-meeting-debt-ceiling-05-16-23/index.html
# Class != article__content-container
# Class != speakable
# Class != entry-content
# Could not parse
# ..........
# Missing JSON key: Index: 2891 ; source: Breitbart News ; URL: https://www.breitbart.com/politics/2023/05/17/gop-aligned-advocacy-group-launches-ad-telling-biden-compromise-debt-ceiling/
# Class != article__content-container
# Class != speakable
# .
# Missing JSON key: Index: 2892 ; source: Breitbart News ; URL: https://www.breitbart.com/clips/2023/05/15/jake-tapper-durham-report-devastating-to-the-fbi-to-a-degree-does-exonerate-donald-trump/
# Class != article__content-container
# Class != speakable
# ..
# Missing JSON key: Index: 2894 ; source: Breitbart News ; URL: https://www.breitbart.com/politics/2023/05/17/study-70-percent-of-abortions-unwanted-coerced-or-inconsistent-with-values/
# Class != article__content-container
# Class != speakable
# ..
# Missing JSON key: Index: 2896 ; source: Breitbart News ; URL: https://www.breitbart.com/politics/2023/05/14/gavin-newsom-backtracks-open-to-cash-reparations-for-slavery-after-all/
# Class != article__content-container
# Class != speakable
# ..
# Missing JSON key: Index: 2898 ; source: Breitbart News ; URL: https://www.breitbart.com/politics/2023/05/14/planned-parenthood-calls-court-packing-term-limits-supreme-court-justices/
# Class != article__content-container
# Class != speakable
# ...
# Missing JSON key: Index: 2901 ; source: Breitbart News ; URL: https://www.breitbart.com/politics/2023/05/16/democrat-donna-deegan-wins-race-for-jacksonville-mayor/
# Class != article__content-container
# Class != speakable
# ...
# Missing JSON key: Index: 2904 ; source: Breitbart News ; URL: https://www.breitbart.com/entertainment/2023/05/14/song-south-disneys-unconscionable-erasure-james-baskett/
# Class != article__content-container
# Class != speakable
# ..
# Missing JSON key: Index: 2906 ; source: Breitbart News ; URL: https://www.breitbart.com/politics/2023/05/15/whistleblower-irs-removed-entire-investigative-team-hunter-biden-probe-doj-request/
# Class != article__content-container
# Class != speakable
# .......
# Missing JSON key: Index: 2913 ; source: Breitbart News ; URL: https://www.breitbart.com/immigration/2023/05/16/ex-obama-biden-migration-adviser-amy-pope-to-run-u-n-agency/
# Class != article__content-container
# Class != speakable
# ...
# Missing JSON key: Index: 2916 ; source: Breitbart News ; URL: https://www.breitbart.com/politics/2023/05/16/kevin-mccarthy-scope-of-debt-ceiling-talks-improving/
# Class != article__content-container
# Class != speakable
# ...
# Missing JSON key: Index: 2919 ; source: Breitbart News ; URL: https://www.breitbart.com/clips/2023/05/15/hutchinson-trump-will-use-durham-report-to-undermine-all-of-law-enforcement/
# Class != article__content-container
# Class != speakable
# ..
# Missing JSON key: Index: 2921 ; source: Breitbart News ; URL: https://www.breitbart.com/politics/2023/05/12/florida-gov-ron-desantis-signs-healthcare-worker-conscience-protections-law/
# Class != article__content-container
# Class != speakable
# .
# Missing JSON key: Index: 2922 ; source: Breitbart News ; URL: https://www.breitbart.com/immigration/2023/05/16/new-york-times-college-grad-americans-are-being-pushed-out-of-coastal-cities/
# Class != article__content-container
# Class != speakable
# ..
# Missing JSON key: Index: 2924 ; source: Breitbart News ; URL: https://www.breitbart.com/tech/2023/05/16/the-lifestyle-murdered-cash-app-creator-bob-lee-was-part-of-san-franciscos-drug-and-sex-party-scene/
# Class != article__content-container
# Class != speakable
# .....Start Time = 2023-06-07 17:52:58.344939
# End Time = 2023-06-07 17:55:43.886417
# Elapsed Time = 0:02:45.541478

# %%
display(slct_tbl_full_df02.iloc[2924])
display(slct_tbl_full_df02.iloc[2924]['article_text'])
# Out:
# text_id                                                        4780
# source_name                                          Breitbart News
# author                                     Lucas Nolan, Lucas Nolan
# title             'The Lifestyle:' Murdered Cash App Creator Bob...
# url               https://www.breitbart.com/tech/2023/05/16/the-...
# publish_date                                   2023-05-16T14:46:43Z
# article_text      <!DOCTYPE html>\n<html class="post-tmpl-defaul...
# content           The brutal murder of successful tech executive...
# article_parsed    \n\n         The brutal murder of successful t...
# Name: 2924, dtype: object
# '<!DOCTYPE html>\n<html class="post-tmpl-default single single-post pid-23974743 tf-single pt-post c-tech" lang="en" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# op: http://media.facebook.com/op# article: http://ogp.me/ns/article#">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width,initial-scale=1" name="viewport"/>\n  <link href="https://ip.breitbart.com" rel="dns-prefetch"/>\n  <link href="https://www.google-analytics.com" rel="dns-prefetch"/>\n  <link href="https://adservice.google.com" rel="dns-prefetch"/>\n  <link href="https://cdn.ampproject.org" rel="dns-prefetch"/>\n  <link href="https://www.gstatic.com" rel="dns-prefetch"/>\n  <link href="https://ib.adnxs.com" rel="dns-prefetch"/>\n  <link href="https://staticxx.facebook.com" rel="dns-prefetch"/>\n  <link href="https://connect.facebook.net" rel="dns-prefetch"/>\n  <link href="https://breitbartproduction.disqus.com" rel="dns-prefetch"/>\n  <link href="https://api.sail-personalize.com" rel="dns-prefetch"/>\n  <link href="https://overlay-track.sailthru.cloud" rel="dns-prefetch"/>\n  <link href="https://ak.sail-horizon.com" rel="dns-prefetch"/>\n  <link href="https://media.sailthru.com" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>\n  <link href="https://fonts.googleapis.com" rel="preconnect"/>\n  <link as="style" href="https://fonts.googleapis.com/css2?family=Bebas+Neue&amp;family=Fjalla+One&amp;display=swap" rel="preload"/>\n  <link as="style" href="/t/style-47451440390268566062.css" rel="preload"/>\n  <link as="script" href="/t/style-47451440390268566062.js" rel="preload"/>\n  <link as="script" href="https://scripts.webcontentassessor.com/scripts/25915dba3f71a41b2d6242657214b496c2beb5fd937e31770246f82c53195453" rel="preload"/>\n  <link as="script" href="https://securepubads.g.doubleclick.net/tag/js/gpt.js" rel="preload"/>\n  <link as="script" href="/t/assets/js/prebid-28019492713839723456.js" rel="preload"/>\n  <link as="script" href="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-9229289037503472" rel="preload"/>\n  <link as="script" href="https://ajax.googleapis.com/ajax/libs/jquery/3.6.0/jquery.min.js" rel="preload"/>\n  <link as="script" href="https://cdnjs.cloudflare.com/ajax/libs/store.js/2.0.12/store.legacy.min.js" rel="preload"/>\n  <link href="https://fonts.googleapis.com/css2?family=Bebas+Neue&amp;family=Fjalla+One&amp;display=swap" rel="stylesheet"/>\n  <link href="/t/style-47451440390268566062.css" rel="stylesheet"/>\n  <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/5.11.2/css/all.min.css" rel="stylesheet"/>\n  <meta content="app-id=722987199" name="apple-itunes-app"/>\n  <meta content="app-id=com.breitbart.app" name="google-play-app"/>\n  <meta content="#FF5500" name="theme-color"/>\n  <meta content="e5213d6c4a07fe85baa34006f2a9a3c977bd8f3a50fd0ab6d2aa93844e0b3303" name="ahrefs-site-verification"/>\n  <meta content="95475020353" property="fb:pages"/>\n  <title>\n   \'The Lifestyle:\' Murdered Cash App Creator Bob Lee Was Part of San Francisco\'s Drug and Sex Party Scene\n  </title>\n  <meta content=\'The brutal murder of successful tech executive Bob Lee has revealed an underground party scene in San Francisco, characterized by recreational drug use and casual sex and known as "The Lifestyle."\' name="description"/>\n  <link href="https://www.breitbart.com/tech/2023/05/16/the-lifestyle-murdered-cash-app-creator-bob-lee-was-part-of-san-franciscos-drug-and-sex-party-scene/" rel="canonical"/>\n  <link href="https://plus.google.com/110812411499982071387" rel="publisher"/>\n  <meta content="en_US" property="og:locale"/>\n  <meta content="article" property="og:type"/>\n  <meta content="\'The Lifestyle:\' Murdered Cash App Creator Bob Lee Was Part of San Francisco\'s Drug and Sex Party Scene" property="og:title"/>\n  <meta content=\'The brutal murder of successful tech executive Bob Lee has revealed an underground party scene in San F ...

# %%
display(slct_tbl_full_df02[slct_tbl_full_df02['article_parsed']==''].head(20))
print(len(slct_tbl_full_df02[slct_tbl_full_df02['article_parsed']=='']))
# Out:
#       text_id source_name                                             author  \
# 64         65         CNN  By <a href="/profiles/adrienne-vogt">Adrienne ...
# 74         75    Fox News                                       Sofie Watson
# 87         88         CNN  By <a href="/profiles/maureen-chowdhury">Maure...
# 255       257         CNN                                                NaN
# 407       566         CNN  By Mike Hayes and <a href="/profiles/maureen-c...
# 541       760    Fox News                                 Danielle Tuntigian
# 659      1173         CNN                                    By Sophie Tanno
# 1056     1737         CNN  By <a href="/profiles/aditi-sandal">Aditi Sang...
# 1261     2025         CNN  By <a href="/profiles/adrienne-vogt">Adrienne ...
# 1948     2785         CNN  By <a href="/profiles/tori-powell">Tori B. Pow...
# 2131     3986         CNN  By <a href="/profiles/elise-hammond">Elise Ham...
# 2354     4210         CNN  By <a href="/profiles/tara-subramaniam">Tara S...
# 2738     4594         CNN                                                NaN
# 2881     4737         CNN  By <a href="/profiles/adrienne-vogt">Adrienne ...
#
#                                                   title  \
# 64               The latest on the US debt ceiling deal
# 74    FOX NEWS CHANNEL TO DEBUT NEW WEEKEND PRIMETIM...
# 87               The latest on the US debt ceiling deal
# 255                         UPDATE: WAR ON GAY PRIDE...
# 407              The latest on the US debt ceiling deal
# 541   SEN. JONI ERNST AND SEN. JEANNE SHAHEEN TO PAR...
# 659                             Russia's war in Ukraine
# 1056  8 killed when driver plows into crowd outside ...
# 1261             George Santos charged in federal probe
# 1948   CNN town hall with former President Donald Trump
# 2131  Special counsel John Durham's report on Trump-...
# 2354                            Russia's war in Ukraine
# 2738  Her mother was a victim of femicide. Now her a...
# 2881  The latest on the debt ceiling talks as defaul...
#
#                                                     url          publish_date  \
# 64    https://www.cnn.com/politics/live-news/us-debt...  2023-05-31T12:35:50Z
# 74    https://press.foxnews.com/2023/06/fox-news-cha...  2023-06-01T18:33:43Z
# 87    https://www.cnn.com/politics/live-news/us-debt...  2023-06-01T13:46:13Z
# 255   https://view.newsletters.cnn.com/messages/1685...  2023-06-01T21:55:37Z
# 407   https://www.cnn.com/politics/live-news/us-debt...  2023-05-30T14:12:09Z
# 541   https://press.foxnews.com/2023/05/sen-joni-ern...  2023-05-30T17:07:24Z
# 659   https://www.cnn.com/europe/live-news/russia-uk...  2023-05-06T09:46:06Z
# 1056  https://www.cnn.com/us/live-news/brownsville-t...  2023-05-08T14:28:31Z
# 1261  https://www.cnn.com/politics/live-news/george-...  2023-05-10T12:52:24Z
# 1948  https://www.cnn.com/politics/live-news/trump-c...  2023-05-10T21:59:54Z
# 2131  https://www.cnn.com/politics/live-news/trump-r...  2023-05-15T19:37:30Z
# 2354  https://www.cnn.com/europe/live-news/russia-uk...  2023-05-16T04:00:32Z
# 2738  https://www.cnn.com/interactive/2023/05/world/...  2023-05-13T02:11:46Z
# 2881  https://www.cnn.com/politics/live-news/biden-m...  2023-05-16T15:22:05Z
#
#                                            article_text  \
# 64    <!DOCTYPE html>\n<html lang="en">\n <head>\n  ...
# 74    <!DOCTYPE html>\n<html lang="en">\n <head>\n  ...
# 87    <!DOCTYPE html>\n<html lang="en">\n <head>\n  ...
# 255   <!DOCTYPE html>\n<html lang="en" xmlns:o="urn:...
# 407   <!DOCTYPE html>\n<html lang="en">\n <head>\n  ...
# 541   <!DOCTYPE html>\n<html lang="en">\n <head>\n  ...
# 659   <!DOCTYPE html>\n<html lang="en">\n <head>\n  ...
# 1056  <!DOCTYPE html>\n<html lang="en">\n <head>\n  ...
# 1261  <!DOCTYPE html>\n<html lang="en">\n <head>\n  ...
# 1948  <!DOCTYPE html>\n<html lang="en">\n <head>\n  ...
# 2131  <!DOCTYPE html>\n<html lang="en">\n <head>\n  ...
# 2354  <!DOCTYPE html>\n<html lang="en">\n <head>\n  ...
# 2738  <!DOCTYPE html>\n<html>\n <head>\n  <meta char...
# 2881  <!DOCTYPE html>\n<html lang="en">\n <head>\n  ...
#
#                                                 content article_parsed
# 64                                                  NaN
# 74                                                  NaN
# 87                                                  NaN
# 255                                                 NaN
# 407                                                 NaN
# 541                                                 NaN
# 659   Russia has been thwarting US-made mobile rocke...
# 1056  Editors Note: This story contains graphic desc...
# 1261  Rep. George Santos, the freshman congressman w...
# 1948  Former President Donald Trump, the frontrunner...
# 2131  Special counsel John Durham concluded that the...
# 2354  Theres been little change on the front lines i...
# 2738  Nicole sleeps next to her aunt Siomara, who ha...
# 2881  The clock is ticking faster on the nations deb...
# 14

# %%
count_p_nan = slct_tbl_full_df02['article_parsed'].isnull().sum()
 
# printing the number of values present
# in the column
print('Number of NaN values present: ' + str(count_p_nan))
# Out:
# Number of NaN values present: 0

# %% [markdown]
# story_str000 = slct_tbl_full_df01['article_text'][0]
# #print(story_str000)

# %% [markdown]
# story_str000_bs = BeautifulSoup(story_str000, 'html.parser')
# rex_art = rex.compile(r'articleBody[\S\s]*\",')
# rex_art.findall(story_str000)

# %% [markdown]
# story_str000_bs.find(class_='articleBody')

# %% [markdown]
# story_str100 = slct_tbl_full_df01['article_text'][1]
# #print(story_str100)

# %% [markdown]
# rex_art100 = rex.compile(r'articleBody[\S\s]+}')
# rex_art100.findall(story_str100)

# %%
slct_tbl_full_df03 = slct_tbl_full_df02[['source_name',
                                         'author',
                                         'title',
                                         'url',
                                         'publish_date',
                                         'article_parsed']]

# %%
slct_tbl_full_df03.to_csv(file_out_path, index=False)

# %% [markdown]
# print(df.head())
# print(df['article_text'][100])

# %% [markdown]
# # 509 Final Project

# %% [markdown]
# ## Rsolve dependencies

# %%
! pip install newsapi-python
# Out:
# Requirement already satisfied: newsapi-python in /Users/davidfriesen/opt/anaconda3/lib/python3.9/site-packages (0.2.7)
# Requirement already satisfied: requests<3.0.0 in /Users/davidfriesen/opt/anaconda3/lib/python3.9/site-packages (from newsapi-python) (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/davidfriesen/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0->newsapi-python) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/davidfriesen/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0->newsapi-python) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/davidfriesen/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0->newsapi-python) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/davidfriesen/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0->newsapi-python) (2.0.4)

# %% [markdown]
# ## Globally import libraries

# %%
import numpy as np
import pandas as pd
import pymysql as mysql
import matplotlib.pyplot as plt
import os
import shutil
import re
import logging
import time
import zipfile
import requests
from bs4 import BeautifulSoup
import datetime
import re
import regex as rex
from collections import defaultdict, Counter
import random
import requests
from bs4 import BeautifulSoup

import sqlite3
import nltk
from string import punctuation
from nltk.corpus import stopwords
import re
import emoji
from nltk.metrics import ConfusionMatrix

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
## Depracated:
# from sklearn.metrics import plot_confusion_matrix
## New version:
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVC
#import mysql.connector

# Set pandas global options
pd.options.display.max_rows = 17

# %% [markdown]
# Data Preprocessing Functions:

# %%
punctuation = set(punctuation) # speeds up comparison
tw_punct = punctuation - {"#"}


# Stopwords - added the 'nan' to this to remove nulls:
# next step could be to add pronouns like she/her, he/him, etc.

sw = stopwords.words("english")
sw = sw + ['nan']

# Two useful regex
whitespace_pattern = re.compile(r"\s+")
hashtag_pattern = re.compile(r"^#[0-9a-zA-Z]+")

def remove_stop(tokens) :
    # modify this function to remove stopwords

    return[t for t in tokens if t not in sw]
 
def remove_punctuation(text, punct_set=tw_punct) : 
    return("".join([ch for ch in text if ch not in punct_set]))

def tokenize(text) : 
    """ Splitting on whitespace rather than the book's tokenize function. That 
        function will drop tokens like '#hashtag' or '2A', which we need for Twitter. """
    
    return([item.lower() for item in whitespace_pattern.split(text)])
    
def remove_url(text):
    return(re.sub(r'http\S+', '', text))

def remove_messy(text): # remove words that give away the source
    text1=re.sub(r'cnn', '', text)
    text2=re.sub(r'fox', '', text1)
    return(re.sub(r'\\n', '', text2))

# two pipelines to either tokenize or simply remove punctuation
# and lowercase as we will need to extract feature words:

full_pipeline = [str.lower, remove_url, remove_messy, remove_punctuation, tokenize, remove_stop]
first_pipeline = [str.lower, remove_url, remove_messy, remove_punctuation]


def prepare(text, pipeline) : 
    tokens = str(text)
    
    for transform in pipeline : 
        tokens = transform(tokens)
        
    return(tokens)

# %%
def conv_features(text,fw) :
     feature_set=dict()
     for word in text.split():
          if word in fw:
               feature_set[word]=True
     return(feature_set)

# %%
today = datetime.date.today()
print(today)
print(type(today))
# Out:
# 2023-06-03
# <class 'datetime.date'>

# %% [markdown]
# ## Connect to NewsAPI client

# %%
from newsapi import NewsApiClient

api_key = os.environ['NewsAPIKey']

# Init
newsapi = NewsApiClient(api_key=api_key)

# %% [markdown]
# ## Pull article info from API

# %% [markdown]
# # /v2/top-headlines/sources
# sources = newsapi.get_sources()
# print(sources)

# %%
def news_api_urls(q=None,
                  s=None,
                  d_from='2023-05-01',
                  d_to='2023-05-31',
                  api_lst=[]):
    all_articles = newsapi.get_everything(q=q,
                                          sources=s,
                                          from_param=d_from,
                                          to=d_to,
                                          language='en',
                                          sort_by='relevancy',
                                          page=1)

    print(type(all_articles))
    print(all_articles)
    #print('Article list: ', all_articles['articles'])
    for article in all_articles['articles']:
        print('Source ID:', article['source']['id'])
        print('Source name:', article['source']['name'])
        print('Author:', article['author'])
        print('Title:', article['title'])
        print('URL:', article['url'])
        print('Publish date:', article['publishedAt'])
        print('Article text:', article['content'], '\n')

    # Create a list of tuples from the dictionary data
    source_data01 = [(a['source']['name'],
                      a['author'],
                      a['title'],
                      a['url'],
                      a['publishedAt'],
                      a['content'])
                     for a in all_articles['articles']]

    api_lst.extend(source_data01)
    #print(api_lst)
    print(len(api_lst))

# %% [markdown]
# ## Connect to API to access URLs

# %% [markdown]
# ### Set API filter parameters

# %%
# Citation comes from Allsides Media Bias Chart

source_lst = ['the-washington-post','cnn','fox-news','breitbart-news']


#date_lst = ['2023-05-30', '2023-05-20']

date_lst = ['2023-05-30']

# Comes from academci text (fill in citation from DF)
#q_word_lst = ['gender OR male OR female OR transgender', 'security AND (social OR national)',
#              'justice OR surveillance', 'healthcare OR "health care"',
#              '(political AND (bias OR party)) OR republican OR democrat OR election', '(policy AND (drug OR "affirmative action")) OR regulate OR regulation']


#date_lst = ['2023-05-20', '2023-05-21', '2023-05-22', '2023-05-23', '2023-05-24', '2023-05-25',
#            '2023-05-26', '2023-05-27', '2023-05-28', '2023-05-29', '2023-05-31']

q_word_lst = ['justice OR surveillance', 'healthcare OR "health care"',
              '(political AND (bias OR party)) OR republican OR democrat OR election',
              'security AND (social OR national)']

# %% [markdown]
# ### Access API

# %%
api_record_lst01 = []
for s in source_lst:
    print(f'Source: {s}')
    for d in date_lst:
        print(f'Date: {d}')
        for q in q_word_lst:
            print(f'Query word: {q}')
            time.sleep(5 + 11 * random.random())
            news_api_urls(q=q,
                          s=s,
                          d_from=d,
                          d_to=d,
                          api_lst=api_record_lst01)
            print(s, d, q)
    time.sleep(10 + 13 * random.random())

print(api_record_lst01)
print(len(api_record_lst01))
# Out:
# Source: the-washington-post
# Date: 2023-05-30
# Query word: gender OR male OR female OR transgender
# <class 'dict'>
# {'status': 'ok', 'totalResults': 5, 'articles': [{'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': None, 'title': 'The revolt of Christian home-schoolers...', 'description': 'The revolt of Christian home-schoolers...\r\n\n \n \n \n (First column, 11th story, link)\r\n\n \r\n\n \r\n\n \n \n Drudge Report Feed needs your support!\xa0\xa0 Become a Patron', 'url': 'https://www.washingtonpost.com/education/interactive/2023/christian-home-schoolers-revolt/', 'urlToImage': 'https://img-s-msn-com.akamaized.net/tenant/amp/entityid/AA1bSwmD.img?h=630&w=1200&m=6&q=60&o=t&l=f&f=jpg&x=428&y=454', 'publishedAt': '2023-05-30T18:25:37Z', 'content': 'Deep Reads features The Washington Posts best immersive reporting and narrative writing.\r\n ROUND HILL, Va. They said goodbye to Aimee outside her elementary school, watching nervously as she joined t… [+31261 chars]'}, {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': 'Paul Waldman', 'title': 'Why fear of change will drive the GOP presidential primary', 'description': 'Striking poll numbers show the divide in American politics is even deeper than you think.', 'url': 'https://www.washingtonpost.com/opinions/2023/05/30/desantis-primary-fear-change/', 'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/3OKXABQD2AI63C7LFNHEQGYVAA.jpg&w=1440', 'publishedAt': '2023-05-30T10:00:00Z', 'content': 'Comment on this story\r\nComment\r\nLook, we know our countrys going in the wrong direction, said Florida Gov. Ron DeSantis as he announced his presidential bid in a glitch-filled Twitter event last week… [+4713 chars]'}, {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': 
chars]
#
# Source ID: the-washington-post
# Source name: The Washington Post
# Author: Julian Mark
# Title: Elizabeth Holmes, disgraced Theranos founder, to report to prison
# URL: https://www.washingtonpost.com/technology/2023/05/30/elizabeth-holmes-prison/
# Publish date: 2023-05-30T15:30:23Z
# Article text: Comment on this story
# Comment
# Elizabeth Holmes, whose descent from tech visionary to convicted felon rocked Silicon Valley, is scheduled to report to prison Tuesday to begin a more than 11-year sen… [+2348 chars]
#
# 5
# the-washington-post 2023-05-30 gender OR male OR female OR transgender
# Query word: security AND (social OR national)
# <class 'dict'>
# {'status': 'ok', 'totalResults': 4, 'articles': [{'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': 'msn', 'title': 'State Dept seeks to expand space diplomacy...', 'description': 'The new agency document details a “strategic framework for space diplomacy.”', 'url': 'https://www.washingtonpost.com/technology/2023/05/30/space-diplomacy-state-department/', 'urlToImage': 'https://img-s-msn-com.akamaized.net/tenant/amp/entityid/AA1bT6lj.img?h=630&w=1200&m=6&q=60&o=t&l=f&f=jpg', 'publishedAt': '2023-05-30T17:00:04Z', 'content': 'State Department seeks to expand its space diplomacy efforts With tensions rising in space, low Earth orbit becoming increasingly congested, and everyday life growing dependent on satellites, the Sta… [+6548 chars]'}, {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': 'Isaac Arnsdorf', 'title': 'Trump campaign braces for Iowa battle as DeSantis team sees an opening', 'description': 'The former president faces well-funded resistance and other headwinds in the GOP’s first nominating contest, even as he pulls ahead in national polls.', 'url': 'https://www.washingtonpost.com/elections/2023/05/30/trump-desantis-iowa-2024-gop-presidential/', 'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/DOEVJ5DCVPDXAYSD467ZYNCJ5U_size-normalized.jpg&w=1440', 'publishedAt': '2023-05-30T10:00:00Z', 'content': 'Comment on this story\r\nComment\r\nDES MOINES Matt Windschitl, the majority leader of the Iowa state House, said he wants a presidential candidate focused on the future and was concerned by former presi… [+12790 chars]'}, {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': 'msn', 'title': 'SHOCK IN RUSSIAN CAPITAL', 'description': 'Drones damaged two residential buildings in a dramatic strike on Moscow after yet another barrage of Russian missiles on Kyiv killed one person and injured more than 12 on Tuesday.', 'url': 'https://www.washingtonpost.com/world/2023/05/30/moscow-drones-kyiv-russia-counteroffensive/', 'urlToImage': 'https://img-s-msn-com.akamaized.net/tenant/amp/entityid/AA1bSPuZ.img?h=630&w=1200&m=6&q=60&o=t&l=f&f=jpg', 'publishedAt': '2023-05-30T13:00:04Z', 'content': 'KYIV, Ukraine A drone attack hit Moscow on Tuesday morning, damaging two residential buildings the first strike on a civilian area of the Russian capital since President Vladimir Putin launched a bru… [+12091 chars]'}, {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': 'Bryan Pietsch', 'title': 'Hvaldimir, alleged Russian spy whale, spotted in Sweden', 'description': 'The beluga whale, known as Hvaldimir, was spotted in Sweden after appearing last week in Oslo. He might be seeking human interaction, one expert said.', 'url': 'https://www.washingtonpost.com/world/2023/05/30/beluga-spy-whale-hvaldimir-sweden-norway/', 'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/3MDHSYY6NUNM3X6F65WAUCJ32I.jpg&w=1440', 'publishedAt': '2023-05-30T06:45:57Z', 'content': 'Comment on this story\r\nComment\r\nThe alleged former Russian spy has spent the past few years bumming around the Norwegian coast, where he made friends with locals and became known for his toothy grin.… [+4611 chars]'}]}
# Source ID: the-washington-post
# Source name: The Washington Post
# Author: msn
# Title: State Dept seeks to expand space diplomacy...
# URL: https://www.washingtonpost.com/technology/2023/05/30/space-diplomacy-state-department/
# Publish date: 2023-05-30T17:00:04Z
# Article text: State Department seeks to expand its space diplomacy efforts With tensions rising in space, low Earth orbit becoming increasingly congested, and everyday life growing dependent on satellites, the Sta… [+6548 chars]
#
# Source ID: the-washington-post
# Source name: The Washington Post
# Author:
# Source ID: the-washington-post
# Source name: The Washington Post
# Author: None
# Title: Alabama Highway sign hacked with white supremacist messages...
# URL: https://www.washingtonpost.com/nation/2023/05/30/alabama-interstate-sign-white-supremacist-memorial-day/
# Publish date: 2023-05-30T16:31:36Z
# Article text: Travelers in Alabama driving on Interstate 65 to parties and barbecues on Memorial Day might have seen messages on digital road signs honoring veterans who died fighting for the United States.
# © Co… [+5919 chars]
#
# Source ID: the-washington-post
# Source name: The Washington Post
# Author: Amber Phillips
# Title: Breaking down the GOP investigation into the Biden family
# URL: https://www.washingtonpost.com/politics/2023/05/30/gop-investigation-hunter-biden-fbi/
# Publish date: 2023-05-30T19:56:33Z
# Article text: Comment on this story
# Comment
# A federal prosecutor may be nearing a decision on whether to charge Hunter Biden with tax offenses and a false statement related to a gun purchase, but House Republica… [+6443 chars]
#
# Source ID: the-washington-post
# Source name: The Washington Post
# Author: David Ovalle
# Title: Appeals court paves way for Purdue Pharma opioids settlement
# URL: https://www.washingtonpost.com/health/2023/05/30/opioids-court-ruling-purdue-pharma-sackler-family/
# Publish date: 2023-05-30T23:52:34Z
# Article text: Comment on this story
# Comment
# A federal appeals court Tuesday cleared the way for drug manufacturer Purdue Pharma to settle thousands of lawsuits regarding its role in fueling the opioid epidemic i… [+5285 chars]
#
# 12
# the-washington-post 2023-05-30 justice OR surveillance
# Query word: healthcare OR "health care"
# <class 'dict'>
# {'status': 'ok', 'totalResults': 2, 'articles': [{'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': 'MSN (The Washington Post)', 'title': 'Striking TV Workers Explain What The Job’s Really Like (And, Therefore, Why They’re On Strike)', 'description': '“TV writers … have been trying to undo misconceptions about their jobs, which they say were never particularly glamorous even in the heyday of network TV. In the age of Netflix and Disney Plus, many writers say, grueling workloads and vanishing job security t…', 'url': 'https://www.washingtonpost.com/arts-entertainment/2023/05/29/writers-strike-myth-facts/', 'urlToImage': 'https://img-s-msn-com.akamaized.net/tenant/amp/entityid/AA1bPt3x.img?h=630&w=1200&m=6&q=60&o=t&l=f&f=jpg&x=511&y=226', 'publishedAt': '2023-05-30T16:03:00Z', 'content': 'The entertainment industrys fourth wall is crumbling as more than 11,000 unionized writers picket for the first time since the 2007 strike, venting more than a decades worth of frustrations about the… [+11377 chars]'}, {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': 'Philip Bump', 'title': 'Trump pledges to win an immigration fight he didn’t win as president', 'description': "The former president insists that he will end birthright citizenship in an echo of his 2016 campaign —\xa0and his presidency. He can't.", 'url': 'https://www.washingtonpost.com/politics/2023/05/30/trump-birthright-citizenship-immigrants/', 'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/DTH6I52T6VEPFAQJ6HIL75XZ2E.jpg&w=1440', 'publishedAt': '2023-05-30T18:30:47Z', 'content': 'Comment on this story\r\nComment\r\nSpeaking in Orlando in November 2015, Republican presidential front-runner Donald Trump revisited the theme that launched his candidacy: immigration.\r\nBreathing heavil… [+5660 chars]'}]}
# Source ID: the-washington-post
# Source name: The Washington Post
# Author: MSN (The Washington Post)
# Title: Striking TV Workers Explain What The Job’s Really Like (And, Therefore, Why They’re On Strike)
# URL: https://www.washingtonpost.com/arts-entertainment/2023/05/29/writers-strike-myth-facts/
# Publish date: 2023-05-30T16:03:00Z
# Article text: The entertainment industrys fourth wall is crumbling as more than 11,000 unionized writers picket for the first time since the 2007 strike, venting more than a decades worth of frustrations about the… [+11377 chars]
#
# Source ID: the-washington-post
# Source name: The Washington Post
# Author: Philip Bump
# Title: Trump pledges to win an immigration fight he didn’t win as president
# URL: https://www.washingtonpost.com/politics/2023/05/30/trump-birthright-citizenship-immigrants/
# Publish date: 2023-05-30T18:30:47Z
# Article text: Comment on this story
# Comment
# Speaking in Orlando in November 2015, Republican presidential front-runner Donald Trump revisited the theme that launched his candidacy: immigration.
# Breathing heavil… [+5660 chars]
#
# 14
# the-washington-post 2023-05-30 healthcare OR "health care"
# Query word: (political AND (bias OR party)) OR republican OR democrat OR election
# <class 'dict'>
# {'status': 'ok', 'totalResults': 16, 'articles': [{'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': None, 'title': 'The revolt of Christian home-schoolers...', 'description': 'The revolt of Christian home-schoolers...\r\n\n \n \n \n (First column, 11th story, link)\r\n\n \r\n\n \r\n\n \n \n Drudge Report Feed needs your support!\xa0\xa0 Become a Patron', 'url': 'https://www.washingtonpost.com/education/interactive/2023/christian-home-schoolers-revolt/', 'urlToImage': 'https://img-s-msn-com.akamaized.net/tenant/amp/entityid/AA1bSwmD.img?h=630&w=1200&m=6&q=60&o=t&l=f&f=jpg&x=428&y=454', 'publishedAt': '2023-05-30T18:25:37Z', 'content': 'Deep Reads features The Washington Posts best immersive reporting and narrative writing.\r\n ROUND HILL, Va. They said goodbye to Aimee outside her elementary school, watching nervously as she joined t… [+31261 chars]'}, {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': 'washington post', 'title': 'Move over, evangelicals. Non-churchgoers now rule GOP...', 'description': 'The voting bloc is quickly growing in size and forcing the party to embrace a populist bent.', 'url': 'https://www.washingtonpost.com/opinions/2023/05/30/republican-party-nonreligious-populists/', 'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/YDI52CJDNGEZ4QIO2RTNS6IMWI_size-normalized.JPG&w=1440', 'publishedAt': '2023-05-30T15:00:04Z', 'content': 'Opinion | Move over, evangelicals. Non-churchgoers now rule the GOP.The religious right might be flexing its muscles as it pushes to restrict abortions and ban gender-affirming surgery for minors in … [+7401 chars]'}, {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': 'Paul Waldman', 'title': 'Why fear of change will drive the GOP presidential primary', 'description': 'Striking poll numbers show the divide in American politics is even deeper than you think.', 'url': 'https://www.washingtonpost.com/opinions/2023/05/30/desantis-primary-fear-change/', 'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/3OKXABQD2AI63C7LFNHEQGYVAA.jpg&w=1440', 'publishedAt': '2023-05-30T10:00:00Z', 'content': 'Comment on this story\r\nComment\r\nLook, we know our countrys going in the wrong direction, said Florida Gov. Ron DeSantis as he announced his presidential bid in a glitch-filled Twitter event last week… [+4713 chars]'}, {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': 'Rachel Siegel', 'title': 'Debt ceiling deal faces first hurdle in Republican-led House', 'description': 'The deal struck by President Biden and House Speaker Kevin McCarthy (R-Calif.) would raise the debt ceiling for two years — past the 2024 elections — while trimming spending.', 'url': 'https://www.washingtonpost.com/business/2023/05/30/debt-ceiling-republicans-house-mccarthy/', 'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/APWCJTTKH5WPEB3YWP3FUVRRZY_size-normalized.JPG&w=1440', 'publishedAt': '2023-05-30T13:30:35Z', 'content': 'Comment on this story\r\nComment\r\nIn the first test of a bipartisan deal on the debt ceiling, a key House committee will meet Tuesday to determine whether the agreement comes to a full vote, all while … [+4016 chars]'}, {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': 'Mariana Alfaro', 'title': 'Report: Utah GOP Rep. Chris Stewart to resign from Congress', 'description': "The departure of Rep. Chris Stewart (R-Utah), an author and retired Air Force pilot, would reduce the GOP's already-slim margin in the House until a replacement could be elected.", 'url': 'https://www.washingtonpost.com/politics/2023/05/30/chris-steward-house-republicans-utah/', 'urlToImage': 'https://www.washingt ...
# Source ID: the-washington-post
# Source name: The Washington Post
# Author: None
# Title: The revolt of Christian home-schoolers...
# URL: https://www.washingtonpost.com/education/interactive/2023/christian-home-schoolers-revolt/
# Publish date: 2023-05-30T18:25:37Z
# Article text: Deep Reads features The Washington Posts best immersive reporting and narrative writing.
#  ROUND HILL, Va. They said goodbye to Aimee outside her elementary school, watching nervously as she joined t… [+31261 chars]
#
# Source ID: the-washington-post
# Source name: The Washington Post
# Author
chars]
#
# Source ID: the-washington-post
# Source name: The Washington Post
# Author: Aaron Gregg
# Title: AI poses ‘risk of extinction’, industry leaders warn
# URL: https://www.washingtonpost.com/business/2023/05/30/ai-poses-risk-extinction-industry-leaders-warn/
# Publish date: 2023-05-30T13:34:14Z
# Article text: Comment on this story
# Comment
# Hundreds of artificial intelligence scientists and tech executives signed a one-sentence letter that succinctly warns AI poses an existential threat to humanity, the l… [+4703 chars]
#
# 34
# the-washington-post 2023-05-30 (policy AND (drug OR "affirmative action")) OR regulate OR regulation
# Date: 2023-05-20
# Query word: gender OR male OR female OR transgender
# <class 'dict'>
# {'status': 'ok', 'totalResults': 5, 'articles': [{'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': None, 'title': 'How mosquitoes use your body chemistry to pick you for their next meal...', 'description': 'How mosquitoes use your body chemistry to pick you for their next meal...\r\n\n \n \n \n (First column, 13th story, link)\r\n\n \r\n\n \r\n\n \n \n Drudge Report Feed needs your support!\xa0\xa0 Become a Patron', 'url': 'https://www.washingtonpost.com/science/2023/05/19/how-mosquitoes-choose-bite-humans/', 'urlToImage': 'https://img-s-msn-com.akamaized.net/tenant/amp/entityid/AA1bpyeN.img?h=630&w=1200&m=6&q=60&o=t&l=f&f=jpg', 'publishedAt': '2023-05-20T02:16:37Z', 'content': '© Andrew Hammond/Andrew Hammond\r\n A female Anopheles gambiae mosquito, one of the species that carries malaria.\r\n To unravel the age-old question of why mosquitoes eat some people alive but spare oth… [+6089 chars]'}, {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': 'Marianne LeVine', 'title': '‘Very uncomfortable’: Scott-Haley 2024 divide sparks GOP tensions in S.C.', 'description': 'The long-overlapping circles of the two Republicans are coming sharply into focus — and stoking anxieties in a state where everyone knows everyone in local politics.', 'url': 'https://www.washingtonpost.com/elections/2023/05/20/nikki-haley-tim-scott-2024-presidential-campaigns/', 'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/VAWV7AW77MI63J4OTJ6CIGFQBQ.jpg&w=1440', 'publishedAt': '2023-05-20T12:09:18Z', 'content': 'Comment on this story\r\nComment\r\nCOLUMBIA, S.C. Shortly after she announced her presidential bid, former South Carolina governor Nikki Haley called her high school classmate and longtime GOP donor Mik… [+11532 chars]'}, {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': 'Rachel Roubein', 'title': 'Republicans deploy new playbook for abortion bans, citing political backlash', 'description': 'GOP lawmakers in North Carolina and Nebraska are casting new 12-week bans as “mainstream,” while Democrats say they are “cruel and extreme”', 'url': 'https://www.washingtonpost.com/politics/2023/05/20/republicans-deploy-new-playbook-abortion-bans-citing-political-backlash/', 'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/7QGJKFFZ5WC3IG7DIPHGQQE4EM_size-normalized.JPG&w=1440', 'publishedAt': '2023-05-20T14:09:20Z', 'content': 'Comment on this story\r\nComment\r\nNebraska antiabortion groups and GOP lawmakers were stunned. In late April,their effort to ban most abortions wastanked by an unlikely person: 80-year-old Sen. Merv Ri… [+12812 chars]'}, {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author': 'Anthony Aycock', 'title': 'Book bans soared in the ’70s, too. The Supreme Court stepped in.', 'description': 'Library book bans are fueling national fights and a new Florida lawsuit. But only one such case has ever ended up before the Supreme Court: the mostly forgotten Island Trees v. Pico.', 'url': 'https://www.washingtonpost.com/history/2023/05/20/book-bans-supreme-court-pico/', 'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/MWVWEWAIZSQFZZTRG2TTVKJRHY.jpg&w=1440', 'publishedAt': '2023-05-20T10:00:53Z', 'content': 'Comment on this story\r\nComment\r\nRecord efforts to ban books are fueling fights in Texas, Virginia and across the country. Just this week, a group including free-speech advocates, authors, parents and… [+7349 chars]'}, {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'}, 'author
# {'status': 'ok', 'totalResults': 10, 'articles': [{'source': {'id': 'breitbart-news', 'name': 'Breitbart News'}, 'author': 'David Ng, David Ng', 'title': "Watch: Paramore Singer Haley Williams Lashes Out at Ron DeSantis Supporters During Concert -- 'You're F**king Dead to Me'", 'description': 'Paramore lead singer Haley Williams lashed out at Ron DeSantis supporters during a recent concert, telling the crowd that "if you vote for Ron DeSantis, you\'re f**king dead to me."', 'url': 'https://www.breitbart.com/entertainment/2023/05/30/watch-paramore-singer-haley-williams-lashes-out-at-ron-desantis-supporters-during-concert-youre-fking-dead-to-me/', 'urlToImage': 'https://media.breitbart.com/media/2023/05/ParamoreHaleyWilliams-640x335.jpg', 'publishedAt': '2023-05-30T21:11:01Z', 'content': 'Paramore lead singer Haley Williams lashed out at Ron DeSantis supporters during a recent concert, telling the crowd that “if you vote for Ron DeSantis, you’re fucking dead to me.”\r\nHaley Williams wa… [+1485 chars]'}, {'source': {'id': 'breitbart-news', 'name': 'Breitbart News'}, 'author': 'Pam Key, Pam Key', 'title': "Hostin: White Female Republicans 'Protect the Patriarchy' -- They 'Fall in Line' with Husbands", 'description': 'ABC legal analyst Sunny Hostin told her co-hosts Tuesday on ABC\'s "The View" that white female Republicans "fall in line" to "protect the patriarchy." | Clips', 'url': 'https://www.breitbart.com/clips/2023/05/30/hostin-white-female-republicans-protect-the-patriarchy-they-fall-in-line-with-husbands/', 'urlToImage': 'https://media.breitbart.com/media/2021/01/Hostin-640x335.jpg', 'publishedAt': '2023-05-30T17:33:27Z', 'content': 'ABC legal analyst Sunny Hostin told her co-hosts Tuesday on ABC’s “The View” that white female Republicans “fall in line” to “protect the patriarchy.”\r\nHostin said, “I have a similar theory. it’s bor… [+1146 chars]'}, {'source': {'id': 'breitbart-news', 'name': 'Breitbart News'}, 'author': 'Joel B. Pollak, Joel B. Pollak', 'title': 'Report: Man Let Go by Gascon After Stabbing Construction Worker Arrested for Murder', 'description': 'A man who avoided jail time, thanks to Los Angeles County District Attorney George Gascón, after stabbing a construction worker in 2020 over "noise" has now been arrested for allegedly murdering his upstairs neighbor.', 'url': 'https://www.breitbart.com/crime/2023/05/30/report-man-let-go-by-gascon-after-stabbing-construction-worker-arrested-for-murder/', 'urlToImage': 'https://media.breitbart.com/media/2022/06/Los-Angeles-New-DA-640x335.jpg', 'publishedAt': '2023-05-30T22:32:00Z', 'content': 'A man who avoided jail time, thanks to Los Angeles County District Attorney George Gascón, after stabbing a construction worker in 2020 over “noise” has now been arrested for allegedly murdering his … [+2233 chars]'}, {'source': {'id': 'breitbart-news', 'name': 'Breitbart News'}, 'author': 'Kristina Wong, Kristina Wong', 'title': "DHS: 'Likely Targets of Potential Violence' in Coming Months Include Churches, Feds", 'description': 'The DHS warned the U.S. is in a "heightened threat environment" in the coming months over the "2024 general election cycle and legislative or judicial decisions pertaining to sociopolitical issues."', 'url': 'https://www.breitbart.com/politics/2023/05/30/dhs-likely-targets-of-potential-violence-in-coming-months-include-churches-feds/', 'urlToImage': 'https://media.breitbart.com/media/2022/05/graffitti-attack-640x335.jpg', 'publishedAt': '2023-05-30T22:24:33Z', 'content': 'The Department of Homeland Security warned in a recent bulletin the U.S. is in a “heightened threat environment” that could portend violence in the coming months over the “2024 general election cycle… [+3364 chars]'}, {'source': {'id': 'breitbart-news', 'name': 'Breitbart News'}, 'author': 'Dylan Gwinn, Dylan Gwinn', 'title': 'WATCH: Blue Jays Pitcher Anthony Bass Issues Apology After Appearing to Endorse Target, Bud Light Boycotts', 'description': 'Blue Jays pitcher Anthony Bass  ...
# Source ID: breitbart-news
# Source name: Breitbart News
# Author
chars]
#
# Source ID: breitbart-news
# Source name: Breitbart News
# Author: Simon Kent, Simon Kent
# Title: LGBTQ Activists Warn Corporate America -- 'You Need to Be Our Ally'
# URL: https://www.breitbart.com/politics/2023/05/30/lgbtq-activists-warn-corporate-america-you-need-to-be-our-ally/
# Publish date: 2023-05-30T09:36:13Z
# Article text: LGBTQ activists called for new campaigns Monday to warn corporate leaders not to heed opposing voices while chastening those who relent in the face of public pressure.
# The call to action follows Tar… [+2652 chars]
#
# Source ID: breitbart-news
# Source name: Breitbart News
# Author: Joel B. Pollak, Joel B. Pollak
# Title: WATCH: Conservative Author Abigail Shrier Rushed by Transgender Activist in Israel
# URL: https://www.breitbart.com/middle-east/2023/05/30/as-transgender-left-protests-haaretz-smears-author-abigail-shrier-in-israel/
# Publish date: 2023-05-30T13:17:48Z
# Article text: A large group of left-wing protesters in a suburb of Tel Aviv, Israel, attempted to intimidate American Jewish author Abigail Shrier during a book event Sunday  — and an Israeli media outlet claimed … [+5854 chars]
#
# Source ID: breitbart-news
# Source name: Breitbart News
# Author: Bob Price, Bob Price
# Title: Texas Governor Calls Special Session for Border Security, Property Tax Measures
# URL: https://www.breitbart.com/border/2023/05/30/texas-governor-calls-special-session-for-border-security-property-tax-measures/
# Publish date: 2023-05-30T11:57:06Z
# Article text: Shortly after the 88th Texas Legislature adjourned sine die, Governor Greg Abbott called them back to what is expected to be several special legislative sessions. The first session, which began Monda… [+3140 chars]
#
# Source ID: breitbart-news
# Source name: Breitbart News
# Author: Paul Bois, Paul Bois
# Title: 'Pennyworth' Star Paloma Faith Slams 'The Little Mermaid' Remake -- 'WTF Is This S***'
# URL: https://www.breitbart.com/entertainment/2023/05/30/pennyworth-star-paloma-faith-scolds-the-little-mermaid-remake-wtf-is-this-s/
# Publish date: 2023-05-30T11:25:13Z
# Article text: Actress and singer Paloma Faith, best known for her work in the show Pennyworth, lambasted Disney’s live-action remake of their beloved animated classic The Little Mermaid, charging it teaches women … [+2956 chars]
#
# 349
# breitbart-news 2023-05-30 gender OR male OR female OR transgender
# Query word: security AND (social OR national)
# ---------------------------------------------------------------------------
# NewsAPIException                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41784\1966222041.py in <module>
#       7             print(f'Query word: {q}')
#       8             time.sleep(5 + 11 * random.random())
# ----> 9             news_api_urls(q=q,
#      10                           s=s,
#      11                           d_from=d,
#
# ~\AppData\Local\Temp\ipykernel_41784\915391522.py in news_api_urls(q, s, d_from, d_to, api_lst)
#       4                   d_to='2023-05-31',
#       5                   api_lst=[]):
# ----> 6     all_articles = newsapi.get_everything(q=q,
#       7                                           sources=s,
#       8                                           from_param=d_from,
#
# c:\Users\Susy\anaconda3\envs\humans\lib\site-packages\newsapi\newsapi_client.py in get_everything(self, q, qintitle, sources, domains, exclude_domains, from_param, to, language, sort_by, page, page_size)
#     332         # Check Status of Request
#     333         if r.status_code != requests.codes.ok:
# --> 334             raise NewsAPIException(r.json())
#     335
#     336         return r.json()
#
# NewsAPIException: {'status': 'error', 'code': 'rateLimited', 'message': 'You have made too many requests recently. Developer accounts are limited to 100 requests over a 24 hour period (50 requests available every 12 hours). Please upgrade to a paid plan if you need more requests.'}

# %% [markdown]
# Article data saved into dataframe:

# %%
api_record_df = pd.DataFrame (list (api_record_lst01),
                                   columns = ['Source','Author','Title','URL','date','content'])

# %% [markdown]
# FOX, CNN, Breitbert, and Washington Post:

# %%
article=[]

for index, rows in api_record_df.iterrows():
    article=[]
    url = api_record_df.at[index,'URL']
    response = requests.get(url)
    time.sleep(5 + 10*random.random())

    soup = BeautifulSoup(response.text, 'html.parser')
    #forcnn
    article_body = soup.find('div', class_='article__content-container')
    
    if article_body is None: #forfoxandbreitbert(sometimes)
        article_body = soup.find('p', class_="speakable")
        if article_body is None: #breitbert(most)
            article_body = soup.find('div', class_='entry-content')
            if article_body is None: #WashPost
                article_body = soup.find('div',class_='article-body')
                #if article_body is None:
                #    break
                                         

    if article_body is not None:
        article_text = article_body.get_text()
        api_record_df.at[index,'full_text']=article_text

# %%
api_record_df['Source'].value_counts()
# Out:
# Fox News               84
# Breitbart News         53
# CNN                    37
# The Washington Post    25
# Name: Source, dtype: int64

# %%
api_record_df.isnull().sum()
# Out:
# Source       0
# Author       2
# Title        0
# URL          0
# date         0
# content      0
# full_text    2
# dtype: int64

# %%
#api_record_df=api_record_df.dropna()

# %%
#api_record_df['Source'].value_counts()

# %% [markdown]
# Save dataframe to csv file:

# %%
api_record_df.to_csv("News_API_FOX_CNN_Breitbert_WAPOST_allcolumns.csv", sep=',')

# %%
#api_record_df.tail(150)

# %%
#api_record_lst01 = [(1, 1, 1), (2, 2, 2), (3, 3, 3), (1, 1, 1), (4, 4, 4), (3, 3, 3)]
#print(api_record_lst01)
api_record_set01 = set(api_record_lst01)
print(api_record_set01)
api_record_lst02 = list(api_record_set01)
print(api_record_lst02)
print(len(api_record_lst02))
# Out:
# {('Fox News', 'Lawrence Richard', "Texas legislature's first special session focusing on border security, cutting property taxes, Abbott reveals", 'https://www.foxnews.com/politics/texas-legislatures-first-special-session-focusing-border-security-cutting-property-taxes-abbott-reveals', '2023-05-30T06:00:33Z', "Texas Gov. Greg Abbott revealed agenda items for the state legislature's first special session late Monday evening a list that includes cutting property taxes and providing funds to secure the U.S.-M… [+2386 chars]"), ('Fox News', 'Paul Steinhauser', 'Potential 2024 Republican presidential contender moves a step closer to launching a campaign', 'https://www.foxnews.com/politics/potential-2024-republican-presidential-contender-moves-step-closer-launching-campaign', '2023-05-30T15:25:48Z', 'Long-time supporters and allies of former New Jersey Gov. Chris Christie are launching a super PAC to back his likely campaign for the 2024 Republican presidential nomination, Fox News has confirmed.… [+3209 chars]'), ('Newsweek', 'Aleks Phillips', "Donald Trump's Pride Merchandise Resurfaces Amid Target, Bud Light Backlash", 'https://www.newsweek.com/donald-trump-pride-merchandise-target-bud-light-backlash-1803353', '2023-05-30T14:50:32Z', "Conservatives calling for boycotts of brands that express support for the LGBTQ+ community have been accused of hypocrisy after Donald Trump's Pride range of merchandise resurfaced on social media.\r\n… [+4367 chars]"), ('Fox News', 'Associated Press', "Greek Education Ministry target of cyberattack, most extensive in country's history", 'https://www.foxnews.com/world/greek-education-ministry-target-cyberattack-extensive-countrys-history', '2023-05-30T16:22:54Z', 'Greeces Education Ministry says it has been targeted in a cyberattack described as the most extensive in the countrys history, aimed at disabling a centralized high school examination platform.\r\nIt s… [+1690 chars]'), ('CNN', 'Nicki Brown', "Colleges will soon have option to hide students' race and ethnicity information on applications submitted through Common App", 'https://www.cnn.com/2023/05/30/us/college-common-app-race-ethnicity/index.html', '2023-05-30T
 chars]'), ('CNN', 'Nicki Brown', "Colleges will soon have option to hide students' race and ethnicity information on applications submitted through Common App", 'https://www.cnn.com/2023/05/30/us/college-common-app-race-ethnicity/index.html', '2023-05-30T17:37:28Z', 'Colleges will soon have the option to hide students race and ethnicity information on applications submitted through Common App, according to the organization. \r\nThe move comes as the Supreme Court i… [+2307 chars]'), ('Newsweek', None, 'The Cloud Revolution in Marketing', 'https://www.newsweek.com/cloud-revolution-marketing-1802918', '2023-05-30T16:00:34Z', 'Like every facet of life, marketing evolves with technology—and nothing typifies recent shifts more aptly than the ongoing cloud revolution. While traditional marketing strategies, such as print ads,… [+7044 chars]'), ('Fox News', 'Landon Mion', 'Minnesota Gov. Walz expected to sign bill legalizing recreational marijuana', 'https://www.foxnews.com/politics/minnesota-governor-expected-sign-bill-legalizing-recreational-marijuana', '2023-05-30T10:20:05Z', "Minnesota Gov. Tim Walz, a Democrat, is expected to sign legislation on Tuesday that would legalize recreational marijuana in the state.\r\nThe bill is headed to the governor's desk after passing throu… [+1705 chars]"), ('Newsweek', 'Nick Reynolds', 'Democrats Unable to Return to D.C. for Massive Debt Deal Vote', 'https://www.newsweek.com/democrats-unable-return-dc-massive-debt-deal-vote-1803463', '2023-05-30T22:05:49Z', 'Two members of the House Democratic minority say they are unable to participate in a massive coming vote on a bipartisan deal to raise the federal debt ceiling before the June 5 deadline to default, … [+3995 chars]'), ('Newsweek', 'Ryan Smith', "Dylan Mulvaney Says She's Been 'Followed' For Months Amid Bud Light Furor", 'https://www.newsweek.com/dylan-mulvaney-says-has-been-followed-months-amid-bud-light-fiasco-1803309', '2023-05-30T13:29:18Z', 'TikTok star Dylan Mulvaney has revealed that she has been "followed on and off" over the past two month ...
# 109

# %% [markdown]
# Create feature word set based on common words in dataset:

# %%
# Tokenize text:

api_record_df['tokens']= api_record_df['full_text'].apply(prepare,
                                                     pipeline=full_pipeline)

# %%
# Clean data into lowercase/no punctuation:

api_record_df['cleaner_text']= api_record_df['full_text'].apply(prepare,
                                                     pipeline=first_pipeline)

# %%
# Add target variable values:

api_record_df['Political_Lean'] = np.where((api_record_df['Source'] == "CNN") | (api_record_df['Source'] == "The Washington Post"), 'Left', 'Right')

# %% [markdown]
# ----------

# %% [markdown]
# Debug corner:

# %%
api_data_df=pd.read_csv('News_API_FOX_CNN_Breitbert_WAPOST_allcolumns.csv')

# %%
#word_dist

# %%
api_record_df['word_count_tokens'] = api_record_df['tokens'].apply(lambda x: len(str(x).split(" ")))
api_record_df['word_count'] = api_record_df['full_text'].apply(lambda x: len(str(x).split(" ")))

# %%
print(api_record_df.iloc[49,6])
# Out:
# CNN
#          —
#
#
#
#       An American living abroad was arrested last week on a charge of threatening US senators and political groups over the number of unsolicited political emails he was receiving, the Justice Department announced Tuesday.
#
#
#       Eric Charles Welton, who has lived in Thailand for more than a decade, allegedly made multiple threatening calls from overseas in 2021 to the offices of North Carolina Republican Sen. Thom Tillis and then-Sen. Richard Burr, according to court documents.
#
#
#       Welton, 51, was arrested Thursday at the Hartsfield-Jackson Atlanta International Airport as he returned to the United States from overseas, according to the Justice Department. He is facing one count of threatening a federal official and faces up to 10 years in prison if convicted.
#
#
#       A lawyer for Welton is not yet listed on the public docket and he has not yet entered a formal plea. CNN has reached out to Burr and Tillis for comment.
#
#
#       During the calls, Welton allegedly threatened to kill people in the senators’ offices, saying that he would “fly back over there” and “put a bullet through each of your heads,” the court documents said. Welton allegedly railed against the number of emails he was getting, telling one staffer that he would find whoever sent the emails and cut off that person’s hands.
#
#
#       Welton also made calls to the White House switchboard and various advocacy groups, the court documents said.
#
#
#       In an interview with agents, Welton’s father said that Welton claimed to have received 600 unsolicited political emails and was “set off by ideas he did not agree with,” according to the court documents.
#
#
#       Welton also threated US Marines working in Thailand, according to court documents, after the US consulate in the country denied a visa application for his wife, who is a citizen of Thailand.
#
#
#       “Now I’m going to kill a bunch of Marines and that’s about all where it is, because you m*ther**kers are so f**king useless and worthless and that’s all you can tell me,” Welton allegedly said in a voicemail to the consulate in November. “So, you want those f**king Marines to live, you f**king contact me back.”
#
#
#       Walton continued by issuing threats to kill “everybody in your f**cking office,” the court documents said.
#
#
#       According to the criminal complaint, Welton lived near the consulate in Thailand and the US evaluated extraditing Welton to the US.

# %%
print(api_record_df.iloc[49,3])
# Out:
# https://www.cnn.com/2023/05/30/politics/us-expatriate-arrested-allegedly-threatening-us-senators/index.html

# %% [markdown]
# Ending of this article coincides with the ending of the full text column in the dataframe

# %%
api_record_df.head(150)
# Out:
#                   Source                          Author  \
# 0    The Washington Post                            None
# 1    The Washington Post                  Amber Phillips
# 2    The Washington Post                    David Ovalle
# 3    The Washington Post       MSN (The Washington Post)
# 4    The Washington Post                     Philip Bump
# ..                   ...                             ...
# 145             Fox News         Bret Baier, Amy Munneke
# 146       Breitbart News      Hannah Bleau, Hannah Bleau
# 147       Breitbart News      Hannah Bleau, Hannah Bleau
# 148       Breitbart News                Pam Key, Pam Key
# 149       Breitbart News  Frances Martel, Frances Martel
#
#                                                  Title  \
# 0    Alabama Highway sign hacked with white suprema...
# 1    Breaking down the GOP investigation into the B...
# 2    Appeals court paves way for Purdue Pharma opio...
# 3    Striking TV Workers Explain What The Job’s Rea...
# 4    Trump pledges to win an immigration fight he d...
# ..                                                 ...
# 145  'Special Report' Spotlight: Private companies ...
# 146  Survey: Jim Justice Leads Joe Manchin in West ...
# 147  Poll: Donald Trump Dominates in West Virginia ...
# 148  Hostin: White Female Republicans 'Protect the ...
# 149  Bricks Fly as Thousands of Chinese Muslims Pro...
#
#                                                    URL                  date  \
# 0    https://www.washingtonpost.com/nation/2023/05/...  2023-05-30T16:31:36Z
# 1    https://www.washingtonpost.com/politics/2023/0...  2023-05-30T19:56:33Z
# 2    https://www.washingtonpost.com/health/2023/05/...  2023-05-30T23:52:34Z
# 3    https://www.washingtonpost.com/arts-entertainm...  2023-05-30T16:03:00Z
# 4    https://www.washingtonpost.com/politics/2023/0...  2023-05-30T18:30:47Z
# ..                                                 ...                   ...
# 145  https://www.foxnews.com/media/special-report-s...  2023-05-30T23:01:07Z
# 146  https://www.breitbart.com/politics/2023/05/30/...  2023-05-30T18:46:22Z
# 147  https://www.breitbart.com/2024-election/2023/0...  2023-05-30T18:24:53Z
# 148  https://www.breitbart.com/clips/2023/05/30/hos...  2023-05-30T17:33:27Z
# 149  https://www.breitbart.com/asia/2023/05/30/bric...  2023-05-30T20:37:21Z
#
#                                                content  \
# 0    Travelers in Alabama driving on Interstate 65 ...
# 1    Comment on this story\r\nComment\r\nA federal ...
# 2    Comment on this story\r\nComment\r\nA federal ...
# 3    The entertainment industrys fourth wall is cru...
# 4    Comment on this story\r\nComment\r\nSpeaking i...
# ..                                                 ...
# 145  Adversaries like Russia and China are increasi...
# 146  West Virginia Gov. Jim Justice (R-WV) is leadi...
# 147  Former President Donald Trump is dominating th...
# 148  ABC legal analyst Sunny Hostin told her co-hos...
# 149  Videos surfacing on social media on Tuesday re...
#
#                                              full_text  \
# 0    Travelers in Alabama driving on Interstate 65 ...
# 1    A federal prosecutor may be nearing a decision...
# 2    A federal appeals court Tuesday cleared the wa...
# 3    The entertainment industry’s fourth wall is cr...
# 4    Speaking in Orlando in November 2015, Republic...
# ..                                                 ...
# 145  Adversaries like Russia and China are increasi...
# 146  \nWest Virginia Gov. Jim Justice (R-WV) is lea...
# 147  \nFormer President Donald Trump is dominating ...
# 148  \nABC legal analyst Sunny Hostin told her co-h...
# 149  \nVideos surfacing on social media on Tuesday ...
#
#                                                 tokens  \
# 0    [travelers, alabama, driving, interstate, 65, ...
# 1    [federal, prosecutor, may, nearing, decision, ...
# 2    [federal, appeals, court, tuesday, cleared, wa...
# 3    [entertainment, industry’s, urth, wall, crumbl...
# 4    [speaking, orlando, november, 2015, republican...
# ..                                                 ...
# 145  [adversaries, like, russia, china, increasing,...
# 146  [, west, virginia, gov, jim, justice, rwv, lea...
# 147  [, rmer, president, donald, trump, dominating,...
# 148  [, abc, legal, analyst, sunny, hostin, told, c...
# 149  [, videos, surfacing, social, media, tuesday, ...
#
#                                           cleaner_text Political_Lean  \
# 0    travelers in alabama driving on interstate 65 ...           Left
# 1    a federal prosecutor may be nearing a decision...           Left
# 2    a federal appeals court tuesday cleared the wa...           Left
# 3    the entertainment industry’s urth wall is crum...           Left
# 4    speaking in orlando in november 2015 republica...           Left
# ..                                                 ...            ...
# 145  adversaries like russia and china are increasi...          Right
# 146  \nwest virginia gov jim justice rwv is leading...          Right
# 147  \nrmer president donald trump is dominating th...          Right
# 148  \nabc legal analyst sunny hostin told her coho...          Right
# 149  \nvideos surfacing on social media on tuesday ...          Right
#
#      word_count  word_count_tokens
# 0            31                 22
# 1            33                 19
# 2            47                 31
# 3            40                 24
# 4            19                 14
# ..          ...                ...
# 145          27                 17
# 146         548                379
# 147         328                264
# 148         237                135
# 149        1139                746
#
# [150 rows x 12 columns]

# %% [markdown]
# ----------------

# %%
# Obtain total counts of words in the entire corpus:

word_dist=Counter([item for sublist in api_record_df['tokens'] 
                   for item in sublist])

# %% [markdown]
# Preparing data for classifier ingestion (as dictionary)

# %%
# generate the dict data to then be filtered through
# the filtered_words list:

news_data=dict()

    
news_data=[(api_record_df.at[index,'cleaner_text'],
            api_record_df.at[index,'Political_Lean']) for (index,row) in api_record_df.iterrows()]

# %% [markdown]
# Determine featureword set:

# %%
word_cutoff=5
feature_words2=[]
for word, count in word_dist.items() :
    #for convention_data_df['word_dist']
    if count > word_cutoff :
        feature_words2.append(word)
            
print(f"With a word cutoff of {word_cutoff}, we have {len(feature_words2)} as features in the model.")
# Out:
# With a word cutoff of 5, we have 1710 as features in the model.

# %%
#feature_words2

# %%
# remove cnn and fox-news from the key featurewords:

#feature_words2.remove("cnn")
#feature_words2.remove("fox")
#feature_words2.remove("wpost")
#feature_words2.remove("breitbart")

# %%
# Filter the data through the feature words set
# determined above:

featuresets=dict()
featuresets = [(conv_features(text,feature_words2), 
                lean) for (text, lean) in news_data]

# %%
#featuresets

# %%
api_record_df['full_text']

# %% [markdown]
# Rough Naive-Bayes Classifier setup and run-through:

# %%
random.seed(42)
random.shuffle(featuresets)
test_size = 20

# %%
test_set=dict()
train_set=dict()
test_set, train_set = featuresets[:test_size], featuresets[test_size:]

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.45

# %%
# Confusion Matrix:

predicted_labels = [classifier.classify(features) for features, 
                    label in test_set]
gold_labels = [label for features, label in test_set]

cm = ConfusionMatrix(gold_labels, predicted_labels)
print(cm.pretty_format(sort_by_count=True, show_percents=True))
# Out:
#       |      R        |
#       |      i      L |
#       |      g      e |
#       |      h      f |
#       |      t      t |
# ------+---------------+
# Right | <10.0%> 55.0% |
#  Left |      . <35.0%>|
# ------+---------------+
# (row = reference; col = test)

# %% [markdown]
# SVM implementation:

# %%
X_train, X_test, Y_train, Y_test = train_test_split(api_record_df['cleaner_text'],
                                                    api_record_df['Political_Lean'],
                                                    test_size=0.2,
                                                    random_state=42,
                                                    stratify=api_record_df['Political_Lean'])

print('Size of Training Data ', X_train.shape[0])
print('Size of Test Data ', X_test.shape[0])
# Out:
# Size of Training Data  159
# Size of Test Data  40

# %%
tfidf = TfidfVectorizer(min_df = 10, ngram_range=(1,2), stop_words="english")
X_train_tf = tfidf.fit_transform(X_train)

# %%
model1 = LinearSVC(random_state=0, tol=1e-5)
model1.fit(X_train_tf, Y_train)
# Out:
# LinearSVC(random_state=0, tol=1e-05)

# %%
X_test_tf = tfidf.transform(X_test)

# %%
Y_pred = model1.predict(X_test_tf)
print ('Accuracy Score - ', accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy Score -  0.875

# %%
Y_pred = model1.predict(X_test_tf)
confusion_matrix(Y_test, Y_pred)
cm = confusion_matrix(Y_test, Y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels = model1.classes_)
disp.plot()
plt.show()

# %% [markdown]
# ## Initiate MySQL connection

# %%
'''Set local environment variables to hide user name & password citation:
https://www.geeksforgeeks.org/how-to-hide-sensitive-credentials-using-python/'''

user_name = "sqluser"
user_pass = "password"

#user_name = os.environ['MySQLUSRAC']
#user_pass = os.environ['MySQLPWDAC']

# Instantiate connection
db_conn = mysql.connect(host='localhost',
                        port=int(3306),
                        user=user_name,
                        passwd=user_pass,
                        db='509_final_proj')

# Create a cursor object
cursor = db_conn.cursor()

# %%
tbl_names = pd.read_sql('SHOW TABLES', db_conn)

display(tbl_names)
print(type(tbl_names))
# Out:
# c:\Users\Susy\anaconda3\envs\humans\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Empty DataFrame
# Columns: [Tables_in_509_final_proj]
# Index: []
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Establish logging policy

# %%
'''Logging citations (see additional code in following code blocks:
OpenAI. (2021). ChatGPT [Computer software]. https://openai.com/;
https://docs.python.org/3/howto/logging.html#logging-basic-example;
https://docs.python.org/3/howto/logging.html#logging-to-a-file;
https://docs.python.org/3/howto/logging-cookbook.html#using-a-rotating-log-file-handler;
https://docs.python.org/3/howto/logging-cookbook.html#using-a-timed-rotating-file-handler'''

# Set up logging
logging.basicConfig(level=logging.INFO,
                    filename='pymysql.log',
                    filemode='a',
                    format='>>>>>>>>>>>>>><<<<<<<<<<<<<<\n%(asctime)s - %(levelname)s - %(message)s')

# %% [markdown]
# ### Update individual tables

# %% [markdown]
# #### Update `news_articles` table from API

# %%
nat_tbl_name = 'nar_temp'
nwa_tbl_name = 'news_articles'

# %%
'''Using cursor and loading into temp file:
OpenAI. (2021). ChatGPT [Computer software]. https://openai.com/;
https://pynative.com/python-mysql-insert-data-into-database-table/'''

# Execute query and measure execution time
start_time = time.time()

# Wipe temp table
try:
    nat_dlt_tble_stmnt = f"""DELETE FROM {nat_tbl_name}"""
    cursor.execute(nat_dlt_tble_stmnt)
    logging.info(f'Successfully executed query:\n{nat_dlt_tble_stmnt}\n\nRecords scanned: {cursor.rowcount}')
except mysql.Error as e:
    logging.error(f'Error executing query:\n{nat_dlt_tble_stmnt}\n\n{e}')
finally:
    end_time = time.time()
    logging.info(f'Time taken: {end_time - start_time:.3f} seconds\n>>>>>>>>>>>>>><<<<<<<<<<<<<<\n\n')

# Execute query and measure execution time
start_time = time.time()

# Load data from CSV file into a temporary table
try:
    nat_csv_load_stmnt = f"""
    INSERT INTO {nat_tbl_name}
    (
    source_name,
    author,
    title,
    url,
    publish_date,
    content
    )
    VALUES (%s, %s, %s, %s, %s, %s)
    """

    # Execute the query with multiple values
    cursor.executemany(nat_csv_load_stmnt, api_record_lst02)
    #cursor.execute(nat_csv_load_stmnt)
    logging.info(f'Successfully executed query:\n{nat_csv_load_stmnt}\n\nRecords scanned: {cursor.rowcount}')
except mysql.Error as e:
    logging.error(f'Error executing query:\n{nat_csv_load_stmnt}\n\n{e}')
finally:
    end_time = time.time()
    logging.info(f'Time taken: {end_time - start_time:.3f} seconds\n>>>>>>>>>>>>>><<<<<<<<<<<<<<\n\n')

# Execute query and measure execution time
start_time = time.time()

# Insert new records into main table
try:
    nwa_load_stmnt = f"""
    INSERT INTO {nwa_tbl_name}
    (
    source_name,
    author,
    title,
    url,
    publish_date,
    content
    )
    SELECT
        tp.source_name,
        tp.author,
        tp.title,
        tp.url,
        tp.publish_date,
        tp.content
    FROM {nat_tbl_name} AS tp
    LEFT JOIN {nwa_tbl_name} AS mn
        ON tp.title = mn.title
            AND CAST(LEFT(tp.publish_date, 10) AS DATE) = CAST(LEFT(mn.publish_date, 10) AS DATE)
            AND tp.author = mn.author
    """
    cursor.execute(nwa_load_stmnt)
    logging.info(f'Successfully executed query:\n{nwa_load_stmnt}\n\nRecords scanned: {cursor.rowcount}')
except mysql.Error as e:
    logging.error(f'Error executing query:\n{nwa_load_stmnt}\n\n{e}')
finally:
    end_time = time.time()
    logging.info(f'Time taken: {end_time - start_time:.3f} seconds\n>>>>>>>>>>>>>><<<<<<<<<<<<<<\n\n')

# Execute query and measure execution time
start_time = time.time()

# Wipe temp table
try:
    cursor.execute(nat_dlt_tble_stmnt)
    logging.info(f'Successfully executed query:\n{nat_dlt_tble_stmnt}\n\nRecords scanned: {cursor.rowcount}')
except mysql.Error as e:
    logging.error(f'Error executing query:\n{nat_dlt_tble_stmnt}\n\n{e}')
finally:
    end_time = time.time()
    logging.info(f'Time taken: {end_time - start_time:.3f} seconds\n>>>>>>>>>>>>>><<<<<<<<<<<<<<\n\n')

# %% [markdown]
# ### Commit changes and close cursor and connection instances

# %%
# Commit the changes to the database
db_conn.commit()

# Close the cursor and database connection
cursor.close()
db_conn.close()
